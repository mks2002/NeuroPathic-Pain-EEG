# %%
# Once the first pipeline is ready, we can extend it with more advanced visualizations and preprocessing steps as needed. and those steps are done here ..

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv('pain_dataset_outputs/files_metadata.csv')
df2 = pd.read_csv('pain_dataset_outputs/files_metadata_V2.csv') 


print(df.shape)
print(df2.shape)
# Out:
# (37, 7)
# (37, 16)

# %% [markdown]
# ### **1) Show problematic files (duration dev > 1s, missing annotation, duplicates)**

# %%
# extract basename and numeric id
df['basename'] = df['file'].apply(lambda x: x.split('\\')[-1])
df['id'] = df['basename'].str.extract(r'ID(\d+)').astype(float).astype('Int64')

# missing IDs (0..43)
expected = set(range(44))
present_ids = set(df['id'].dropna().astype(int))
missing_ids = sorted(expected - present_ids)
print('Missing IDs:', missing_ids)

# duplicates
dups = df['id'][df['id'].duplicated(keep=False)]
print('Duplicate ID entries (check these files):')
print(df[df['id'].isin(dups)][['basename','file']])
# Out:
# Missing IDs: [12, 17, 28, 29, 32, 34, 36, 42]
# Duplicate ID entries (check these files):
#       basename                      file
# 6  ID15(1).gdf  Pain-Dataset\ID15(1).gdf
# 7     ID15.gdf     Pain-Dataset\ID15.gdf

# %%
# duration deviations (more than 1s)
df['duration_dev_sec'] = df['duration_sec'] - 600.0
bad_dur = df[df['duration_dev_sec'].abs() > 1.0][['basename','duration_sec','duration_dev_sec','n_samples']]
print('Files with duration deviating > 1s from 600s:')
print(bad_dur.to_string(index=False))

# files with unusual annotations
print('Distinct annotation sets and counts:')
print(df['annotations'].value_counts())
# Out:
# Files with duration deviating > 1s from 600s:
#    basename  duration_sec  duration_dev_sec  n_samples
#     ID1.gdf       605.824             5.824     151456
#    ID10.gdf       605.952             5.952     151488
#    ID11.gdf       605.824             5.824     151456
#    ID13.gdf       605.824             5.824     151456
#    ID14.gdf       605.824             5.824     151456
# ID15(1).gdf       605.824             5.824     151456
#    ID15.gdf       605.824             5.824     151456
#    ID16.gdf       605.824             5.824     151456
#    ID18.gdf       605.824             5.824     151456
#    ID19.gdf       605.824             5.824     151456
#     ID2.gdf       605.824             5.824     151456
#    ID20.gdf       605.824             5.824     151456
#    ID21.gdf       605.824             5.824     151456
#    ID22.gdf       605.824             5.824     151456
#    ID23.gdf       605.952             5.952     151488
#    ID24.gdf       605.952             5.952     151488
#    ID25.gdf       605.824             5.824     151456
#    ID27.gdf       605.952             5.952     151488
#     ID3.gdf       605.824             5.824     151456
#    ID30.gdf       605.824             5.824     151456
#    ID31.gdf       605.824             5.824     151456
#    ID33.gdf       605.824             5.824     151456
#    ID35.gdf       605.824             5.824     151456
#    ID37.gdf       605.824             5.824     151456
#    ID38.gdf       605.824             5.824     151456
#    ID39.gdf       605.824             5.824     151456
#     ID4.gdf       605.824             5.824     151456
#    ID40.gdf       605.824             5.824     151456
#    ID41.gdf       605.824             5.824     151456
#    ID43.gdf       605.824             5.824     151456
#     ID5.gdf       605.824             5.824     151456
#     ID6.gdf       605.824             5.824     151456
#     ID7.gdf       605.824             5.824     151456
#     ID8.gdf       605.824             5.824     151456
#     ID9.gdf       605.952             5.952     151488
# Distinct annotation sets and counts:
# annotations
# ['33024' '33025' '33029']    35
# ['33024' '33025']             2
# Name: count, dtype: int64

# %% [markdown]
# ### **2) Inspect annotations inside a given GDF file to get event times (run per-file)**

# %%
import mne
from pathlib import Path
f = Path('Pain-Dataset') / 'ID1.gdf'   # change filename as needed
raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
print('Sampling rate:', raw.info['sfreq'])
print('Channels:', raw.info['ch_names'][:6], '...')

# Show annotations (onset, duration, description)
ann = raw.annotations
print('Annotations object:', ann)
if ann is not None:
    for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
        print(f'onset(s)={onset:.3f}, dur={duration:.3f}, desc={desc}')
else:
    print('No annotations found in this file.')
# Out:
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029

# %%
import mne
from pathlib import Path

# Path to the folder containing .gdf files
folder_path = Path('Pain-Dataset')

# Loop through all .gdf files in the folder
for f in folder_path.glob('*.gdf'):
    print(f"Processing file: {f.name}")
    
    # Read the raw EEG data
    raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
    
    # Print the sampling rate and first 6 channel names
    print('Sampling rate:', raw.info['sfreq'])
    print('Channels:', raw.info['ch_names'][:6], '...')
    
    # Show annotations (onset, duration, description)
    ann = raw.annotations
    print('Annotations object:', ann)
    
    if ann is not None:
        for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
            print(f'onset(s)={onset:.3f}, dur={duration:.3f}, desc={desc}')
    else:
        print('No annotations found in this file.')
    
    print('-' * 40)  # Print a separator between files
# Out:
# Processing file: ID0.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 2 segments: 33024 (1), 33025 (1)>
# onset(s)=0.000, dur=0.004, desc=33024
# onset(s)=300.000, dur=0.004, desc=33025
# ----------------------------------------
# Processing file: ID1.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID10.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID11.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID13.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID14.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID15(1).gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID15.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID16.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID18.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID19.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID2.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID20.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID21.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID22.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID23.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID24.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID25.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID26.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 2 segments: 33024 (1), 33025 (1)>
# onset(s)=0.000, dur=0.004, desc=33024
# onset(s)=300.000, dur=0.004, desc=33025
# ----------------------------------------
# Processing file: ID27.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID3.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID30.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID31.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID33.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID35.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID37.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID38.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID39.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID4.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID40.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID41.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID43.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID5.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID6.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID7.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID8.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID9.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------

# %%
import mne
import pandas as pd
from pathlib import Path

DATA_DIR = Path('Pain-Dataset')

summary_rows = []

for f in sorted(DATA_DIR.glob('*.gdf')):
    try:
        raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
        ann = raw.annotations
        sampling_rate = raw.info['sfreq']
        ch_names = ','.join(raw.info['ch_names'])
        
        if ann is not None and len(ann) > 0:
            for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
                summary_rows.append({
                    'file': f.name,
                    'sampling_rate': sampling_rate,
                    'num_channels': len(raw.info['ch_names']),
                    'onset_s': round(onset, 3),
                    'duration_s': round(duration, 3),
                    'event_code': desc
                })
        else:
            summary_rows.append({
                'file': f.name,
                'sampling_rate': sampling_rate,
                'num_channels': len(raw.info['ch_names']),
                'onset_s': None,
                'duration_s': None,
                'event_code': 'None'
            })
    except Exception as e:
        print(f"Error reading {f.name}: {e}")

# Create DataFrame
df_ann = pd.DataFrame(summary_rows)

# Save for later
df_ann.to_csv('annotations_summary.csv', index=False)

print("✅ Annotation summary saved as annotations_summary.csv")
display(df_ann.head())
# Out:
# ✅ Annotation summary saved as annotations_summary.csv
#       file  sampling_rate  num_channels  onset_s  duration_s event_code
# 0  ID0.gdf          250.0            24      0.0       0.004      33024
# 1  ID0.gdf          250.0            24    300.0       0.004      33025
# 2  ID1.gdf          250.0            24      5.0       0.004      33024
# 3  ID1.gdf          250.0            24    305.0       0.004      33025
# 4  ID1.gdf          250.0            24    605.0       0.004      33029

# %% [markdown]
# ### **Save the Data into EYE OPEN(EO) and EYE CLOSE(EC) Segments and save it for further use**

# %%
'''
# here we dont take the ID0, ID26 special cases into consideration ...

import mne
from pathlib import Path
import numpy as np

base = Path('Pain-Dataset')
save_dir = Path('Segments')
save_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]
    
    # --- Find event onsets safely ---
    codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
    start1 = codes.get('33024', 0.0)      # EO start
    start2 = codes.get('33025', start1 + 300.0)  # EC start
    end    = codes.get('33029', start2 + 300.0)  # recording end or EC end fallback

    # --- Fix missing/extra durations ---
    # EO desired = [5s, 305s], EC = [305s, 605s]
    eo_start = max(start1, 5.0)
    eo_end   = eo_start + 300.0
    ec_start = eo_end
    ec_end   = ec_start + 300.0

    # Clamp within available recording length
    eo_end = min(eo_end, total_dur)
    ec_end = min(ec_end, total_dur)

    # Round down to nearest multiple of 5
    def round_down_5(x):
        return np.floor(x / 5) * 5

    eo_start = round_down_5(eo_start)
    eo_end   = round_down_5(eo_end)
    ec_start = round_down_5(ec_start)
    ec_end   = round_down_5(ec_end)

    # Skip if too short (<5s)
    if ec_end - ec_start < 5 or eo_end - eo_start < 5:
        print(f"⚠️ Skipped (too short): {f.name}")
        continue

    # --- Crop segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

    # --- Save both segments ---
    eo.save(save_dir / f"{f.stem}_EO_raw.fif", overwrite=True)
    ec.save(save_dir / f"{f.stem}_EC_raw.fif", overwrite=True)

    # Optionally save arrays
    np.save(save_dir / f"{f.stem}_EO.npy", eo.get_data())
    np.save(save_dir / f"{f.stem}_EC.npy", ec.get_data())

    print(f"✅ EO: {eo_start:.1f}-{eo_end:.1f}s | EC: {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n🎯 Segmentation complete: all EO & EC files saved cleanly.")


'''

# %%
"""
# Here alll files are stored in same folder ...

import mne
from pathlib import Path
import numpy as np

base = Path('Pain-Dataset')
save_dir = Path('Segments')
save_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]

    # --- Handle ID0 and ID26 separately ---
    if 'ID0' in f.name or 'ID26' in f.name:
        eo_start, eo_end = 0.0, 300.0
        ec_start = eo_end
        ec_end = np.floor(total_dur / 5) * 5  # round down to multiple of 5
        print(f"⚙️ Using fixed timing for {f.name}")
    else:
        # --- Normal case: derive timings from annotations ---
        codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
        start1 = codes.get('33024', 0.0)       # EO start
        start2 = codes.get('33025', start1 + 300.0)  # EC start
        end = codes.get('33029', start2 + 300.0)     # End

        # EO desired = [5s, 305s], EC = [305s, 605s]
        eo_start = max(start1, 5.0)
        eo_end = eo_start + 300.0
        ec_start = eo_end
        ec_end = ec_start + 300.0

        # Clamp within total duration
        eo_end = min(eo_end, total_dur)
        ec_end = min(ec_end, total_dur)

        # Round to nearest multiple of 5
        def round_down_5(x):
            return np.floor(x / 5) * 5

        eo_start = round_down_5(eo_start)
        eo_end = round_down_5(eo_end)
        ec_start = round_down_5(ec_start)
        ec_end = round_down_5(ec_end)

        # Skip if segment too short
        if ec_end - ec_start < 5 or eo_end - eo_start < 5:
            print(f"⚠️ Skipped (too short): {f.name}")
            continue

    # --- Crop both segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

    # --- Save both segments ---
    eo.save(save_dir / f"{f.stem}_EO_raw.fif", overwrite=True)
    ec.save(save_dir / f"{f.stem}_EC_raw.fif", overwrite=True)

    np.save(save_dir / f"{f.stem}_EO.npy", eo.get_data())
    np.save(save_dir / f"{f.stem}_EC.npy", ec.get_data())

    print(f"✅ EO: {eo_start:.1f}-{eo_end:.1f}s | EC: {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n🎯 Segmentation complete: all EO & EC files saved cleanly.")

"""


"""

import mne
import numpy as np
from pathlib import Path


# directory containing your processed files
DATA_DIR = Path("Segments")  
SAMPLING_RATE = 250  # Hz
EXPECTED_SEGMENT_SEC = [300, 600]  # 5 min or 10 min possible

print(f"\nChecking all .fif and .npy files in: {DATA_DIR}\n{'='*80}")

for file in sorted(DATA_DIR.glob("*")):
    if file.suffix == ".fif":
        raw = mne.io.read_raw_fif(file, preload=False, verbose="ERROR")
        n_channels = len(raw.ch_names)
        n_samples = raw.n_times
        duration_sec = n_samples / SAMPLING_RATE

        # Status check
        status = (
            "✅ Exact 5 min"
            if abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[FIF] {file.name}")
        print(f"   Channels: {n_channels}, Samples: {n_samples}, Duration: {duration_sec:.2f}s → {status}")

    elif file.suffix == ".npy":
        data = np.load(file)
        if data.ndim == 2:
            n_channels, n_samples = data.shape
        elif data.ndim == 3:
            n_channels, n_samples, _ = data.shape
        else:
            n_channels, n_samples = "?", "?"

        duration_sec = n_samples / SAMPLING_RATE if isinstance(n_samples, int) else "?"
        status = (
            "✅ Exact 5 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[NPY] {file.name}")
        print(f"   Shape: {data.shape}, Duration: {duration_sec}s → {status}")

print("\nCheck complete ✅\n")


"""

# %%
import mne
from pathlib import Path
import numpy as np

base = Path('Pain-Dataset')
save_dir = Path('Segments')
save_dir.mkdir(exist_ok=True)

# --- Create subfolders ---
eo_dir = save_dir / 'EO'
ec_dir = save_dir / 'EC'
eo_dir.mkdir(exist_ok=True)
ec_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]

    # --- Handle ID0 and ID26 separately ---
    if 'ID0' in f.name or 'ID26' in f.name:
        eo_start, eo_end = 0.0, 300.0
        ec_start = eo_end
        ec_end = np.floor(total_dur / 5) * 5  # round down to multiple of 5
        print(f"⚙️ Using fixed timing for {f.name}")
    else:
        # --- Normal case: derive timings from annotations ---
        codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
        start1 = codes.get('33024', 0.0)        # EO start
        start2 = codes.get('33025', start1 + 300.0)  # EC start
        end = codes.get('33029', start2 + 300.0)     # End

        # EO desired = [5s, 305s], EC = [305s, 605s]
        eo_start = max(start1, 5.0)
        eo_end = eo_start + 300.0
        ec_start = eo_end
        ec_end = ec_start + 300.0

        # Clamp within total duration
        eo_end = min(eo_end, total_dur)
        ec_end = min(ec_end, total_dur)

        # Round to nearest multiple of 5
        def round_down_5(x):
            return np.floor(x / 5) * 5

        eo_start = round_down_5(eo_start)
        eo_end = round_down_5(eo_end)
        ec_start = round_down_5(ec_start)
        ec_end = round_down_5(ec_end)

        # Skip if segment too short
        if ec_end - ec_start < 5 or eo_end - eo_start < 5:
            print(f"⚠️ Skipped (too short): {f.name}")
            continue

    # --- Check for overlap or repetition ---
    if np.isclose(eo_end, ec_start):
        print(f"⚠️ Boundary overlap at {eo_end:.1f}s for {f.name}")

    # --- Crop both segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

    # --- Save both segments in separate subfolders ---
    eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
    ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)

    np.save(eo_dir / f"{f.stem}_EO.npy", eo.get_data())
    np.save(ec_dir / f"{f.stem}_EC.npy", ec.get_data())

    print(f"✅ EO: {eo_start:.1f}-{eo_end:.1f}s | EC: {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n🎯 Segmentation complete: EO & EC files saved in respective subfolders.")
# Out:
# 📁 Processing ID0.gdf
# ⚙️ Using fixed timing for ID0.gdf
# ⚠️ Boundary overlap at 300.0s for ID0.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID0_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID0_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID0_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID0_EC.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID0_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID0_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# [done]
# ✅ EO: 0.0-300.0s | EC: 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID1.gdf
# ⚠️ Boundary overlap at 305.0s for ID1.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID1_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID1_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID1_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID1_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID10.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID1_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID1_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID10.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID10_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID10_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID10_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID10_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID10_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID10_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID11.gdf
# ⚠️ Boundary overlap at 305.0s for ID11.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID11_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID11_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID11_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID11_EC.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID11_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID11_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID13.gdf
# ⚠️ Boundary overlap at 305.0s for ID13.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID13_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID13_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID13_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID13_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID13_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID13_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID14.gdf
# ⚠️ Boundary overlap at 305.0s for ID14.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID14_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID14_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID14_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID14_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15(1).gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID14_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID14_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID15(1).gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15(1)_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15(1)_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15(1)_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15(1)_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15(1)_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15(1)_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID15.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID16.gdf
# ⚠️ Boundary overlap at 305.0s for ID16.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID16_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID16_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID16_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID16_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID16_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID16_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID18.gdf
# ⚠️ Boundary overlap at 305.0s for ID18.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID18_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID18_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID18_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID18_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID19.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID18_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID18_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID19.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID19_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID19_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID19_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID19_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID19_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID19_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID2.gdf
# ⚠️ Boundary overlap at 305.0s for ID2.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID2_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID2_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID2_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID2_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID20.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID2_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID2_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID20.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID20_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID20_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID20_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID20_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID20_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID20_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID21.gdf
# ⚠️ Boundary overlap at 305.0s for ID21.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID21_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID21_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID21_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID21_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID22.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID21_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID21_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID22.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID22_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID22_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID22_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID22_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID22_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID22_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID23.gdf
# ⚠️ Boundary overlap at 305.0s for ID23.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID23_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID23_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID23_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID23_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID23_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID23_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID24.gdf
# ⚠️ Boundary overlap at 305.0s for ID24.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID24_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID24_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID24_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID24_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID25.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID24_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID24_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID25.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID25_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID25_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID25_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID25_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID25_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID25_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID26.gdf
# ⚙️ Using fixed timing for ID26.gdf
# ⚠️ Boundary overlap at 300.0s for ID26.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID26_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID26_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID26_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID26_EC.fif
# [done]
# ✅ EO: 0.0-300.0s | EC: 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID27.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID26_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID26_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID27.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID27_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID27_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID27_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID27_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID3.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID27_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID27_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID3.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID3_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID3_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID3_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID3_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID30.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID3_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID3_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID30.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID30_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID30_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID30_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID30_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID30_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID30_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID31.gdf
# ⚠️ Boundary overlap at 305.0s for ID31.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID31_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID31_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID31_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID31_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID33.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID31_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID31_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID33.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID33_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID33_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID33_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID33_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID33_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID33_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID35.gdf
# ⚠️ Boundary overlap at 305.0s for ID35.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID35_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID35_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID35_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID35_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID35_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID35_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID37.gdf
# ⚠️ Boundary overlap at 305.0s for ID37.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID37_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID37_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID37_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID37_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID38.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID37_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID37_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID38.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID38_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID38_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID38_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID38_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID39.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID38_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID38_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID39.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID39_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID39_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID39_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID39_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID4.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID39_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID39_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID4.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID4_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID4_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID4_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID4_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID4_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID4_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID40.gdf
# ⚠️ Boundary overlap at 305.0s for ID40.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID40_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID40_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID40_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID40_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID41.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID40_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID40_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID41.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID41_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID41_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID41_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID41_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID43.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID41_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID41_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID43.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID43_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID43_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID43_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID43_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID5.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID43_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID43_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID5.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID5_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID5_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID5_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID5_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID5_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID5_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID6.gdf
# ⚠️ Boundary overlap at 305.0s for ID6.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID6_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID6_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID6_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID6_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID7.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID6_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID6_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID7.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID7_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID7_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID7_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID7_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID7_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID7_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID8.gdf
# ⚠️ Boundary overlap at 305.0s for ID8.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID8_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID8_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID8_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID8_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID9.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID8_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID8_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID9.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID9_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID9_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID9_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID9_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 🎯 Segmentation complete: EO & EC files saved in respective subfolders.
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID9_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID9_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)

# %% [markdown]
# ### **Run ICA for EO Component**

# %%
# method 2 

import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define paths ---
example_file = Path("Segments\EO\ID0_EO.fif")  # your actual file path
OUTPUT_DIR = Path("pain_dataset_outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

# --- Load .fif file ---
raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

# --- Check basic info ---
print(raw_example.info)

# --- Rename FP1, FP2 if needed ---
rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}

if rename_dict:
    print("Renaming channels:", rename_dict)
    raw_example.rename_channels(rename_dict)

# --- Set standard montage ---
try:
    raw_example.set_montage('standard_1020', on_missing='ignore')
    print(" Montage set successfully with 'standard_1020'")
except Exception as e:
    print(" Montage assignment issue:", e)



# --- Run ICA ---
ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
ica.fit(raw_example)

# --- Plot ICA components ---
ica.plot_components()  # Shows interactively

# --- Save component grid image ---
fig = ica.plot_components(show=False)
fig.savefig(OUTPUT_DIR / f"{example_file.stem}_ica_components_EO_V1.png")
plt.close(fig)

print(f"✅ ICA completed and image saved for {example_file.name}")
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: FP1, FP2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T7, T8, P7, ...
#  chs: 24 EEG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 24
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: X>
# >
# Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
#  Montage set successfully with 'standard_1020'
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\454234970.py:36: RuntimeWarning: The data has not been high-pass filtered. For good ICA performance, it should be high-pass filtered (e.g., with a 1.0 Hz lower bound) before fitting ICA.
#   ica.fit(raw_example)
# Fitting ICA took 1.1s.
# <MNEFigure size 975x731.5 with 15 Axes>
# ✅ ICA completed and image saved for ID0_EO.fif

# %%
# method 2 

import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define paths ---
example_file = Path("Segments\EO\ID0_EO.fif")  # your actual file path
OUTPUT_DIR = Path("pain_dataset_outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

# --- Load .fif file ---
raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

# --- Check basic info ---
print(raw_example.info)

# --- Rename FP1, FP2 if needed ---
rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}

if rename_dict:
    print("Renaming channels:", rename_dict)
    raw_example.rename_channels(rename_dict)

# --- Set standard montage ---
try:
    raw_example.set_montage('standard_1020', on_missing='ignore')
    print(" Montage set successfully with 'standard_1020'")
except Exception as e:
    print(" Montage assignment issue:", e)

# --- Filter and reference before ICA ---
raw_example.pick_types(eeg=True)
raw_example.set_eeg_reference('average', projection=True)
raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

# --- Run ICA ---
ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
ica.fit(raw_ica)

# --- Plot ICA components ---
ica.plot_components()  # Shows interactively

# --- Save component grid image ---
fig = ica.plot_components(show=False)
fig.savefig(OUTPUT_DIR / f"{example_file.stem}_ica_components_EO_V2.png")
plt.close(fig)

print(f"✅ ICA completed and image saved for {example_file.name}")
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: FP1, FP2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T7, T8, P7, ...
#  chs: 24 EEG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 24
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: X>
# >
# Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
#  Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# <MNEFigure size 975x731.5 with 15 Axes>
# ✅ ICA completed and image saved for ID0_EO.fif

# %% [markdown]
# ### **For all EO files**

# %%
import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define input/output paths ---
eo_dir = Path("Segments/EO")               # Folder with EO .fif files
OUTPUT_DIR = Path("pain_dataset_outputs")
output_subdir = OUTPUT_DIR / "EO-ICA-Components"  # New subfolder for ICA images
output_subdir.mkdir(parents=True, exist_ok=True)

print(f"\n📁 Searching for EO files in: {eo_dir.resolve()}")

# --- Iterate through all EO .fif files ---
for example_file in sorted(eo_dir.glob("*.fif")):
    print(f"\n⚙️ Processing file: {example_file.name}")

    # --- Load .fif file ---
    raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

    # --- Rename FP1, FP2 if needed ---
    rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}
    if rename_dict:
        print("🔤 Renaming channels:", rename_dict)
        raw_example.rename_channels(rename_dict)

    # --- Set standard montage ---
    try:
        raw_example.set_montage('standard_1020', on_missing='ignore')
        print("🧠 Montage set successfully with 'standard_1020'")
    except Exception as e:
        print(f"⚠️ Montage assignment issue: {e}")

    # --- Filter and reference before ICA ---
    raw_example.pick_types(eeg=True)
    raw_example.set_eeg_reference('average', projection=True)
    raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

    # --- Run ICA ---
    ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
    ica.fit(raw_ica)

    # --- Plot ICA components (optional interactive view) ---
    # ica.plot_components()  #  want to view interactively

    # --- Save ICA component grid image ---
    fig = ica.plot_components(show=False)
    save_path = output_subdir / f"{example_file.stem}_ICA_Components_EO_V2.png"
    fig.savefig(save_path, dpi=150)
    plt.close(fig)

    print(f"✅ ICA completed and image saved: {save_path.name}")

print(f"\n🎯 All EO ICA component plots saved in: {output_subdir.resolve()}")
# Out:
# 📁 Searching for EO files in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO
#
# ⚙️ Processing file: ID0_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID0_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID10_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID10_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID11_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID11_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID13_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.4s.
# ✅ ICA completed and image saved: ID13_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID14_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID14_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID15(1)_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID15(1)_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID15_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID15_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID16_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.6s.
# ✅ ICA completed and image saved: ID16_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID18_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID18_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID19_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# ✅ ICA completed and image saved: ID19_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID1_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# ✅ ICA completed and image saved: ID1_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID20_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# ✅ ICA completed and image saved: ID20_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID21_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID21_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID22_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# ✅ ICA completed and image saved: ID22_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID23_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID23_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID24_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.3s.
# ✅ ICA completed and image saved: ID24_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID25_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.6s.
# ✅ ICA completed and image saved: ID25_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID26_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.5s.
# ✅ ICA completed and image saved: ID26_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID27_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.6s.
# ✅ ICA completed and image saved: ID27_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID2_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.4s.
# ✅ ICA completed and image saved: ID2_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID30_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.8s.
# ✅ ICA completed and image saved: ID30_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID31_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 2.1s.
# ✅ ICA completed and image saved: ID31_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID33_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.8s.
# ✅ ICA completed and image saved: ID33_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID35_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.9s.
# ✅ ICA completed and image saved: ID35_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID37_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 3.2s.
# ✅ ICA completed and image saved: ID37_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID38_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID38_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID39_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 2.0s.
# ✅ ICA completed and image saved: ID39_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID3_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.5s.
# ✅ ICA completed and image saved: ID3_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID40_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID40_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID41_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID41_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID43_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID43_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID4_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID4_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID5_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID5_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID6_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID6_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID7_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID7_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID8_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID8_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID9_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# C:\Users\User\AppData\Local\Temp\ipykernel_2828\3404519601.py:40: RuntimeWarning: Using n_components=15 (resulting in n_components_=15) may lead to an unstable mixing matrix estimation because the ratio between the largest (24) and smallest (9.5e-06) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 9
#   ica.fit(raw_ica)
# ✅ ICA completed and image saved: ID9_EO_ICA_Components_EO_V2.png
#
# 🎯 All EO ICA component plots saved in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\pain_dataset_outputs\EO-ICA-Components

# %% [markdown]
# ### **Save EO and EC file Combinely in Segment Joined Folder and remove last extra 1 value**

# %%
import mne
from pathlib import Path
import numpy as np

# Directories
base = Path('Pain-Dataset')
save_dir = Path('Segment-Joined')
save_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    
    # Load raw data
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]

    # --- Handle ID0 and ID26 separately ---
    if 'ID0' in f.name or 'ID26' in f.name:
        eo_start, eo_end = 0.0, 300.0
        ec_start = eo_end
        ec_end = np.floor(total_dur / 5) * 5  # round down to multiple of 5
        print(f"⚙️ Using fixed timing for {f.name}")
    else:
        # --- Normal case: derive timings from annotations ---
        codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
        start1 = codes.get('33024', 0.0)       # EO start
        start2 = codes.get('33025', start1 + 300.0)  # EC start
        end = codes.get('33029', start2 + 300.0)     # End

        # EO desired = [5s, 305s], EC = [305s, 605s]
        eo_start = max(start1, 5.0)
        eo_end = eo_start + 300.0
        ec_start = eo_end
        ec_end = ec_start + 300.0

        # Clamp within total duration
        eo_end = min(eo_end, total_dur)
        ec_end = min(ec_end, total_dur)

        # Round to nearest multiple of 5
        def round_down_5(x):
            return np.floor(x / 5) * 5

        eo_start = round_down_5(eo_start)
        eo_end = round_down_5(eo_end)
        ec_start = round_down_5(ec_start)
        ec_end = round_down_5(ec_end)

        # Skip if segment too short
        if ec_end - ec_start < 5 or eo_end - eo_start < 5:
            print(f"⚠️ Skipped (too short): {f.name}")
            continue

    # --- Crop both segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

     # --- Debugging: Check shapes of data before removing rows ---
    print(f"Before removing last row:")
    print(f"EO data shape: {eo.get_data().shape} (channels, samples)")
    print(f"EC data shape: {ec.get_data().shape} (channels, samples)")

    # --- Remove last row if necessary ---
    if 'ID0' in f.name or 'ID26' in f.name:
        # For ID0 and ID26, remove last row from both EO and EC
        eo_data = eo.get_data()[:, :-1]  # Remove last row
        ec_data = ec.get_data()[:, :-1]  # Remove last row
    else: 
        # for Normal cases
        eo_data = eo.get_data()[:, :-1]  # Remove last row
        ec_data = ec.get_data()[:, :-1]  # Remove last row


    # --- Debugging: Check shapes after removing rows ---
    print(f"After removing last row:")
    print(f"EO data shape: {eo_data.shape} (channels, samples)")
    print(f"EC data shape: {ec_data.shape} (channels, samples)")

    # --- Check the number of channels before merging ---
    print(f"Number of channels in EO: {eo_data.shape[0]}")
    print(f"Number of channels in EC: {ec_data.shape[0]}")    

    # --- Merge EO and EC data ---
    combined_data = np.concatenate([eo_data, ec_data], axis=1)

    # --- Debugging: Check the shape of combined data ---
    print(f"Combined data shape: {combined_data.shape} (channels, samples)")

    # --- Save the merged data ---
    combined_raw = mne.io.RawArray(combined_data, info=eo.info)
    
    # Save merged .fif file
    combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)

    # Save merged .npy file
    np.save(save_dir / f"{f.stem}_combine.npy", combined_data)

    print(f"✅ Merged EO & EC: {eo_start:.1f}-{eo_end:.1f}s | {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n Segmentation and merging complete: all joint files saved successfully.")
# Out:
# 📁 Processing ID0.gdf
# ⚙️ Using fixed timing for ID0.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 73751) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 73750) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 148750) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=148750
#     Range : 0 ... 148749 =      0.000 ...   594.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID0_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID0_combine.fif
# [done]
# ✅ Merged EO & EC: 0.0-300.0s | 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID1.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID0_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID1_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID1_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID10.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID1_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID10_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID10_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID11.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID10_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID11_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID11_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID13.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID11_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID13_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID13_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID14.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID13_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID14_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID14_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15(1).gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID14_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15(1)_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15(1)_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15(1)_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID16.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID16_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID16_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID18.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID16_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID18_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID18_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID19.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID18_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID19_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID19_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID2.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID19_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID2_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID2_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID20.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID2_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID20_combine.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID20_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID20_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID21.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID21_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID21_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID22.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID21_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID22_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID22_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID23.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID22_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID23_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID23_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID24.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID23_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID24_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID24_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID25.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID24_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID25_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID25_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID26.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID25_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ⚙️ Using fixed timing for ID26.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 73751) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 73750) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 148750) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=148750
#     Range : 0 ... 148749 =      0.000 ...   594.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID26_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID26_combine.fif
# [done]
# ✅ Merged EO & EC: 0.0-300.0s | 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID27.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID26_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID27_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID27_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID3.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID27_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID3_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID3_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID30.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID3_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID30_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID30_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID31.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID30_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID31_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID31_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID33.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID31_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID33_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID33_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID35.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID33_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID35_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID35_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID37.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID35_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID37_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID37_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID38.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID37_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID38_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID38_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID39.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID38_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID39_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID39_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID4.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID39_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID4_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID4_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID40.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID4_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID40_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID40_combine.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID40_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID41.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID41_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID41_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID43.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID41_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID43_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID43_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID5.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID43_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID5_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID5_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID6.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID5_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID6_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID6_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID7.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID6_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID7_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID7_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID8.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID7_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID8_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID8_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID9.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID8_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID9_combine.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_1428\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID9_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID9_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
#  Segmentation and merging complete: all joint files saved successfully.

# %%
import mne
import numpy as np
from pathlib import Path

# Directory containing your processed files
DATA_DIR = Path("Segment-Joined")  # This is your new folder with combined files
SAMPLING_RATE = 250  # Hz,
EXPECTED_SEGMENT_SEC = [300, 600]  # 5 min or 10 min possible

print(f"\nChecking all .fif and .npy files in: {DATA_DIR}\n{'='*80}")

for file in sorted(DATA_DIR.glob("*")):
    if file.suffix == ".fif":
        raw = mne.io.read_raw_fif(file, preload=False, verbose="ERROR")
        n_channels = len(raw.ch_names)
        n_samples = raw.n_times
        duration_sec = n_samples / SAMPLING_RATE

        # Status check based on expected segment lengths
        status = (
            "✅ Exact 5 min"
            if abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[FIF] {file.name}")
        print(f"   Channels: {n_channels}, Samples: {n_samples}, Duration: {duration_sec:.2f}s → {status}")

    elif file.suffix == ".npy":
        data = np.load(file)
        if data.ndim == 2:
            n_channels, n_samples = data.shape
        elif data.ndim == 3:
            n_channels, n_samples, _ = data.shape
        else:
            n_channels, n_samples = "?", "?"

        duration_sec = n_samples / SAMPLING_RATE if isinstance(n_samples, int) else "?"
        status = (
            "✅ Exact 5 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[NPY] {file.name}")
        print(f"   Shape: {data.shape}, Duration: {duration_sec}s → {status}")

print("\nCheck complete ✅\n")
# Out:
# Checking all .fif and .npy files in: Segment-Joined
# ================================================================================
# [FIF] ID0_combine.fif
#    Channels: 24, Samples: 148750, Duration: 595.00s → ⚠️ Irregular length
# [NPY] ID0_combine.npy
#    Shape: (24, 148750), Duration: 595.0s → ⚠️ Irregular length
# [FIF] ID10_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID10_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID11_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID11_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID13_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID13_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID14_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID14_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID15(1)_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID15(1)_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID15_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID15_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID16_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID16_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID18_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID18_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID19_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID19_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID1_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID1_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID20_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID20_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID21_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID21_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID22_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID22_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID23_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID23_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID24_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID24_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID25_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID25_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID26_combine.fif
#    Channels: 24, Samples: 148750, Duration: 595.00s → ⚠️ Irregular length
# [NPY] ID26_combine.npy
#    Shape: (24, 148750), Duration: 595.0s → ⚠️ Irregular length
# [FIF] ID27_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID27_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID2_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID2_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID30_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID30_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID31_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID31_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID33_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID33_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID35_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID35_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID37_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID37_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID38_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID38_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID39_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID39_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID3_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID3_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID40_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID40_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID41_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID41_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID43_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID43_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID4_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID4_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID5_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID5_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID6_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID6_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID7_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID7_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID8_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID8_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID9_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID9_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
#
# Check complete ✅
