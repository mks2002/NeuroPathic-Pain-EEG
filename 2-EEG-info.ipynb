# %%
# Once the first pipeline is ready, we can extend it with more advanced visualizations and preprocessing steps as needed. and those steps are done here ..

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv('pain_dataset_outputs/files_metadata.csv')

print(df.shape)
# Out:
# (37, 7)

# %% [markdown]
# ### **1) Show problematic files (duration dev > 1s, missing annotation, duplicates)**

# %%
# extract basename and numeric id
df['basename'] = df['file'].apply(lambda x: x.split('\\')[-1])
df['id'] = df['basename'].str.extract(r'ID(\d+)').astype(float).astype('Int64')

# missing IDs (0..43)
expected = set(range(44))
present_ids = set(df['id'].dropna().astype(int))
missing_ids = sorted(expected - present_ids)
print('Missing IDs:', missing_ids)

# duplicates
dups = df['id'][df['id'].duplicated(keep=False)]
print('Duplicate ID entries (check these files):')
print(df[df['id'].isin(dups)][['basename','file']])
# Out:
# Missing IDs: [12, 17, 28, 29, 32, 34, 36, 42]
# Duplicate ID entries (check these files):
#       basename                      file
# 6  ID15(1).gdf  Pain-Dataset\ID15(1).gdf
# 7     ID15.gdf     Pain-Dataset\ID15.gdf

# %%
# duration deviations (more than 1s)
df['duration_dev_sec'] = df['duration_sec'] - 600.0
bad_dur = df[df['duration_dev_sec'].abs() > 1.0][['basename','duration_sec','duration_dev_sec','n_samples']]
print('Files with duration deviating > 1s from 600s:')
print(bad_dur.to_string(index=False))

# files with unusual annotations
print('Distinct annotation sets and counts:')
print(df['annotations'].value_counts())
# Out:
# Files with duration deviating > 1s from 600s:
#    basename  duration_sec  duration_dev_sec  n_samples
#     ID1.gdf       605.824             5.824     151456
#    ID10.gdf       605.952             5.952     151488
#    ID11.gdf       605.824             5.824     151456
#    ID13.gdf       605.824             5.824     151456
#    ID14.gdf       605.824             5.824     151456
# ID15(1).gdf       605.824             5.824     151456
#    ID15.gdf       605.824             5.824     151456
#    ID16.gdf       605.824             5.824     151456
#    ID18.gdf       605.824             5.824     151456
#    ID19.gdf       605.824             5.824     151456
#     ID2.gdf       605.824             5.824     151456
#    ID20.gdf       605.824             5.824     151456
#    ID21.gdf       605.824             5.824     151456
#    ID22.gdf       605.824             5.824     151456
#    ID23.gdf       605.952             5.952     151488
#    ID24.gdf       605.952             5.952     151488
#    ID25.gdf       605.824             5.824     151456
#    ID27.gdf       605.952             5.952     151488
#     ID3.gdf       605.824             5.824     151456
#    ID30.gdf       605.824             5.824     151456
#    ID31.gdf       605.824             5.824     151456
#    ID33.gdf       605.824             5.824     151456
#    ID35.gdf       605.824             5.824     151456
#    ID37.gdf       605.824             5.824     151456
#    ID38.gdf       605.824             5.824     151456
#    ID39.gdf       605.824             5.824     151456
#     ID4.gdf       605.824             5.824     151456
#    ID40.gdf       605.824             5.824     151456
#    ID41.gdf       605.824             5.824     151456
#    ID43.gdf       605.824             5.824     151456
#     ID5.gdf       605.824             5.824     151456
#     ID6.gdf       605.824             5.824     151456
#     ID7.gdf       605.824             5.824     151456
#     ID8.gdf       605.824             5.824     151456
#     ID9.gdf       605.952             5.952     151488
# Distinct annotation sets and counts:
# annotations
# ['33024' '33025' '33029']    35
# ['33024' '33025']             2
# Name: count, dtype: int64

# %% [markdown]
# ### **2) Inspect annotations inside a given GDF file to get event times (run per-file)**

# %%
import mne
from pathlib import Path
f = Path('Pain-Dataset') / 'ID1.gdf'   # change filename as needed
raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
print('Sampling rate:', raw.info['sfreq'])
print('Channels:', raw.info['ch_names'][:6], '...')

# Show annotations (onset, duration, description)
ann = raw.annotations
print('Annotations object:', ann)
if ann is not None:
    for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
        print(f'onset(s)={onset:.3f}, dur={duration:.3f}, desc={desc}')
else:
    print('No annotations found in this file.')
# Out:
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029

# %%
import mne
from pathlib import Path

# Path to the folder containing .gdf files
folder_path = Path('Pain-Dataset')

# Loop through all .gdf files in the folder
for f in folder_path.glob('*.gdf'):
    print(f"Processing file: {f.name}")
    
    # Read the raw EEG data
    raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
    
    # Print the sampling rate and first 6 channel names
    print('Sampling rate:', raw.info['sfreq'])
    print('Channels:', raw.info['ch_names'][:6], '...')
    
    # Show annotations (onset, duration, description)
    ann = raw.annotations
    print('Annotations object:', ann)
    
    if ann is not None:
        for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
            print(f'onset(s)={onset:.3f}, dur={duration:.3f}, desc={desc}')
    else:
        print('No annotations found in this file.')
    
    print('-' * 40)  # Print a separator between files
# Out:
# Processing file: ID0.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 2 segments: 33024 (1), 33025 (1)>
# onset(s)=0.000, dur=0.004, desc=33024
# onset(s)=300.000, dur=0.004, desc=33025
# ----------------------------------------
# Processing file: ID1.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID10.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID11.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID13.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID14.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID15(1).gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID15.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID16.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID18.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID19.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID2.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID20.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID21.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID22.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID23.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID24.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID25.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID26.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 2 segments: 33024 (1), 33025 (1)>
# onset(s)=0.000, dur=0.004, desc=33024
# onset(s)=300.000, dur=0.004, desc=33025
# ----------------------------------------
# Processing file: ID27.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID3.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID30.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID31.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID33.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID35.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID37.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID38.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID39.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID4.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID40.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID41.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID43.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID5.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID6.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID7.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID8.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID9.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------

# %%
import mne
import pandas as pd
from pathlib import Path

DATA_DIR = Path('Pain-Dataset')

summary_rows = []

for f in sorted(DATA_DIR.glob('*.gdf')):
    try:
        raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
        ann = raw.annotations
        sampling_rate = raw.info['sfreq']
        ch_names = ','.join(raw.info['ch_names'])
        
        if ann is not None and len(ann) > 0:
            for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
                summary_rows.append({
                    'file': f.name,
                    'sampling_rate': sampling_rate,
                    'num_channels': len(raw.info['ch_names']),
                    'onset_s': round(onset, 3),
                    'duration_s': round(duration, 3),
                    'event_code': desc
                })
        else:
            summary_rows.append({
                'file': f.name,
                'sampling_rate': sampling_rate,
                'num_channels': len(raw.info['ch_names']),
                'onset_s': None,
                'duration_s': None,
                'event_code': 'None'
            })
    except Exception as e:
        print(f"Error reading {f.name}: {e}")

# Create DataFrame
df_ann = pd.DataFrame(summary_rows)

# Save for later
df_ann.to_csv('annotations_summary.csv', index=False)

print("✅ Annotation summary saved as annotations_summary.csv")
display(df_ann.head())
# Out:
# ✅ Annotation summary saved as annotations_summary.csv
#       file  sampling_rate  num_channels  onset_s  duration_s event_code
# 0  ID0.gdf          250.0            24      0.0       0.004      33024
# 1  ID0.gdf          250.0            24    300.0       0.004      33025
# 2  ID1.gdf          250.0            24      5.0       0.004      33024
# 3  ID1.gdf          250.0            24    305.0       0.004      33025
# 4  ID1.gdf          250.0            24    605.0       0.004      33029

# %% [markdown]
# ### **Save the Data into EYE OPEN(EO) and EYE CLOSE(EC) Segments and save it for further use**

# %%
'''
# here we dont take the ID0, ID26 special cases into consideration ...

import mne
from pathlib import Path
import numpy as np

base = Path('Pain-Dataset')
save_dir = Path('Segments')
save_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]
    
    # --- Find event onsets safely ---
    codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
    start1 = codes.get('33024', 0.0)      # EO start
    start2 = codes.get('33025', start1 + 300.0)  # EC start
    end    = codes.get('33029', start2 + 300.0)  # recording end or EC end fallback

    # --- Fix missing/extra durations ---
    # EO desired = [5s, 305s], EC = [305s, 605s]
    eo_start = max(start1, 5.0)
    eo_end   = eo_start + 300.0
    ec_start = eo_end
    ec_end   = ec_start + 300.0

    # Clamp within available recording length
    eo_end = min(eo_end, total_dur)
    ec_end = min(ec_end, total_dur)

    # Round down to nearest multiple of 5
    def round_down_5(x):
        return np.floor(x / 5) * 5

    eo_start = round_down_5(eo_start)
    eo_end   = round_down_5(eo_end)
    ec_start = round_down_5(ec_start)
    ec_end   = round_down_5(ec_end)

    # Skip if too short (<5s)
    if ec_end - ec_start < 5 or eo_end - eo_start < 5:
        print(f"⚠️ Skipped (too short): {f.name}")
        continue

    # --- Crop segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

    # --- Save both segments ---
    eo.save(save_dir / f"{f.stem}_EO_raw.fif", overwrite=True)
    ec.save(save_dir / f"{f.stem}_EC_raw.fif", overwrite=True)

    # Optionally save arrays
    np.save(save_dir / f"{f.stem}_EO.npy", eo.get_data())
    np.save(save_dir / f"{f.stem}_EC.npy", ec.get_data())

    print(f"✅ EO: {eo_start:.1f}-{eo_end:.1f}s | EC: {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n🎯 Segmentation complete: all EO & EC files saved cleanly.")


'''

# %%
import mne
from pathlib import Path
import numpy as np

base = Path('Pain-Dataset')
save_dir = Path('Segments')
save_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]

    # --- Handle ID0 and ID26 separately ---
    if 'ID0' in f.name or 'ID26' in f.name:
        eo_start, eo_end = 0.0, 300.0
        ec_start = eo_end
        ec_end = np.floor(total_dur / 5) * 5  # round down to multiple of 5
        print(f"⚙️ Using fixed timing for {f.name}")
    else:
        # --- Normal case: derive timings from annotations ---
        codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
        start1 = codes.get('33024', 0.0)       # EO start
        start2 = codes.get('33025', start1 + 300.0)  # EC start
        end = codes.get('33029', start2 + 300.0)     # End

        # EO desired = [5s, 305s], EC = [305s, 605s]
        eo_start = max(start1, 5.0)
        eo_end = eo_start + 300.0
        ec_start = eo_end
        ec_end = ec_start + 300.0

        # Clamp within total duration
        eo_end = min(eo_end, total_dur)
        ec_end = min(ec_end, total_dur)

        # Round to nearest multiple of 5
        def round_down_5(x):
            return np.floor(x / 5) * 5

        eo_start = round_down_5(eo_start)
        eo_end = round_down_5(eo_end)
        ec_start = round_down_5(ec_start)
        ec_end = round_down_5(ec_end)

        # Skip if segment too short
        if ec_end - ec_start < 5 or eo_end - eo_start < 5:
            print(f"⚠️ Skipped (too short): {f.name}")
            continue

    # --- Crop both segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

    # --- Save both segments ---
    eo.save(save_dir / f"{f.stem}_EO_raw.fif", overwrite=True)
    ec.save(save_dir / f"{f.stem}_EC_raw.fif", overwrite=True)

    np.save(save_dir / f"{f.stem}_EO.npy", eo.get_data())
    np.save(save_dir / f"{f.stem}_EC.npy", ec.get_data())

    print(f"✅ EO: {eo_start:.1f}-{eo_end:.1f}s | EC: {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n🎯 Segmentation complete: all EO & EC files saved cleanly.")
# Out:
# 📁 Processing ID0.gdf
# ⚙️ Using fixed timing for ID0.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID0_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID0_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID0_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID0_EC_raw.fif
# [done]
# ✅ EO: 0.0-300.0s | EC: 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID1.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID1_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID1_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID1_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID1_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID10.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID10_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID10_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID10_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID10_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID11.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID11_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID11_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID11_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID11_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID13.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID13_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID13_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID13_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID13_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID14.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID14_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID14_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID14_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID14_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15(1).gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID15(1)_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID15(1)_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID15(1)_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID15(1)_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID15_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID15_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID15_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID15_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID16.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID16_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID16_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID16_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID16_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID18.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID18_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID18_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID18_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID18_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID19.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID19_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID19_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID19_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID19_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID2.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID2_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID2_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID2_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID2_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID20.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID20_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID20_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID20_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID20_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID21.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID21_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID21_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID21_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID21_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID22.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID22_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID22_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID22_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID22_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID23.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID23_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID23_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID23_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID23_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID24.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID24_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID24_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID24_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID24_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID25.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID25_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID25_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID25_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID25_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID26.gdf
# ⚙️ Using fixed timing for ID26.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID26_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID26_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID26_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID26_EC_raw.fif
# [done]
# ✅ EO: 0.0-300.0s | EC: 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID27.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID27_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID27_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID27_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID27_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID3.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID3_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID3_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID3_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID3_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID30.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID30_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID30_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID30_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID30_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID31.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID31_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID31_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID31_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID31_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID33.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID33_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID33_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID33_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID33_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID35.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID35_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID35_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID35_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID35_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID37.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID37_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID37_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID37_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID37_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID38.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID38_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID38_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID38_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID38_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID39.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID39_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID39_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID39_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID39_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID4.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID4_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID4_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID4_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID4_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID40.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID40_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID40_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID40_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID40_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID41.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID41_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID41_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID41_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID41_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID43.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID43_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID43_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID43_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID43_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID5.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID5_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID5_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID5_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID5_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID6.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID6_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID6_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID6_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID6_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID7.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID7_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID7_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID7_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID7_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID8.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID8_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID8_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID8_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID8_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID9.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID9_EO_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID9_EO_raw.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID9_EC_raw.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\ID9_EC_raw.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 🎯 Segmentation complete: all EO & EC files saved cleanly.

# %%
import mne
import numpy as np
from pathlib import Path


# directory containing your processed files
DATA_DIR = Path("Segments")  
SAMPLING_RATE = 250  # Hz
EXPECTED_SEGMENT_SEC = [300, 600]  # 5 min or 10 min possible

print(f"\nChecking all .fif and .npy files in: {DATA_DIR}\n{'='*80}")

for file in sorted(DATA_DIR.glob("*")):
    if file.suffix == ".fif":
        raw = mne.io.read_raw_fif(file, preload=False, verbose="ERROR")
        n_channels = len(raw.ch_names)
        n_samples = raw.n_times
        duration_sec = n_samples / SAMPLING_RATE

        # Status check
        status = (
            "✅ Exact 5 min"
            if abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[FIF] {file.name}")
        print(f"   Channels: {n_channels}, Samples: {n_samples}, Duration: {duration_sec:.2f}s → {status}")

    elif file.suffix == ".npy":
        data = np.load(file)
        if data.ndim == 2:
            n_channels, n_samples = data.shape
        elif data.ndim == 3:
            n_channels, n_samples, _ = data.shape
        else:
            n_channels, n_samples = "?", "?"

        duration_sec = n_samples / SAMPLING_RATE if isinstance(n_samples, int) else "?"
        status = (
            "✅ Exact 5 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[NPY] {file.name}")
        print(f"   Shape: {data.shape}, Duration: {duration_sec}s → {status}")

print("\nCheck complete ✅\n")
# Out:
# Checking all .fif and .npy files in: Segments
# ================================================================================
# [NPY] ID0_EC.npy
#    Shape: (24, 73751), Duration: 295.004s → ⚠️ Irregular length
# [FIF] ID0_EC_raw.fif
#    Channels: 24, Samples: 73751, Duration: 295.00s → ⚠️ Irregular length
# [NPY] ID0_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID0_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID10_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID10_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID10_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID10_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID11_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID11_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID11_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID11_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID13_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID13_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID13_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID13_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID14_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID14_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID14_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID14_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID15(1)_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID15(1)_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID15(1)_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID15(1)_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID15_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID15_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID15_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID15_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID16_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID16_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID16_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID16_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID18_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID18_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID18_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID18_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID19_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID19_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID19_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID19_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID1_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID1_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID1_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID1_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID20_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID20_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID20_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID20_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID21_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID21_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID21_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID21_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID22_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID22_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID22_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID22_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID23_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID23_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID23_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID23_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID24_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID24_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID24_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID24_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID25_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID25_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID25_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID25_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID26_EC.npy
#    Shape: (24, 73751), Duration: 295.004s → ⚠️ Irregular length
# [FIF] ID26_EC_raw.fif
#    Channels: 24, Samples: 73751, Duration: 295.00s → ⚠️ Irregular length
# [NPY] ID26_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID26_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID27_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID27_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID27_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID27_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID2_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID2_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID2_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID2_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID30_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID30_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID30_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID30_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID31_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID31_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID31_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID31_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID33_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID33_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID33_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID33_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID35_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID35_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID35_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID35_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID37_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID37_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID37_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID37_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID38_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID38_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID38_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID38_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID39_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID39_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID39_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID39_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID3_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID3_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID3_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID3_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID40_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID40_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID40_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID40_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID41_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID41_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID41_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID41_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID43_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID43_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID43_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID43_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID4_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID4_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID4_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID4_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID5_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID5_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID5_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID5_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID6_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID6_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID6_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID6_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID7_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID7_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID7_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID7_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID8_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID8_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID8_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID8_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID9_EC.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID9_EC_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
# [NPY] ID9_EO.npy
#    Shape: (24, 75001), Duration: 300.004s → ✅ Exact 5 min
# [FIF] ID9_EO_raw.fif
#    Channels: 24, Samples: 75001, Duration: 300.00s → ✅ Exact 5 min
#
# Check complete ✅
