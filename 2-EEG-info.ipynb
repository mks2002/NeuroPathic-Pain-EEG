# %%
# Once the first pipeline is ready, we can extend it with more advanced visualizations and preprocessing steps as needed. and those steps are done here ..

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv('pain_dataset_outputs/files_metadata.csv')
df2 = pd.read_csv('pain_dataset_outputs/files_metadata_V2.csv') 


print(df.shape)
print(df2.shape)
# Out:
# (37, 7)
# (37, 16)

# %%
print(df.head())
# Out:
#                     file  sfreq  n_channels  n_samples  duration_sec  \
# 0   Pain-Dataset\ID0.gdf  250.0          24     149952       599.808
# 1   Pain-Dataset\ID1.gdf  250.0          24     151456       605.824
# 2  Pain-Dataset\ID10.gdf  250.0          24     151488       605.952
# 3  Pain-Dataset\ID11.gdf  250.0          24     151456       605.824
# 4  Pain-Dataset\ID13.gdf  250.0          24     151456       605.824
#
#                                             ch_names  \
# 0  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...
# 1  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...
# 2  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...
# 3  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...
# 4  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...
#
#                  annotations
# 0          ['33024' '33025']
# 1  ['33024' '33025' '33029']
# 2  ['33024' '33025' '33029']
# 3  ['33024' '33025' '33029']
# 4  ['33024' '33025' '33029']

# %%
print(df2.head())
# Out:
#                     file  sfreq  n_channels  n_samples  duration_sec  \
# 0   Pain-Dataset\ID0.gdf  250.0          24     149952       599.808
# 1   Pain-Dataset\ID1.gdf  250.0          24     151456       605.824
# 2  Pain-Dataset\ID10.gdf  250.0          24     151488       605.952
# 3  Pain-Dataset\ID11.gdf  250.0          24     151456       605.824
# 4  Pain-Dataset\ID13.gdf  250.0          24     151456       605.824
#
#                                             ch_names ch_types bads  lowpass  \
# 0  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...      EEG   []    125.0
# 1  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...      EEG   []    125.0
# 2  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...      EEG   []    125.0
# 3  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...      EEG   []    125.0
# 4  ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', '...      EEG   []    125.0
#
#    highpass  meas_date  device_info                             subject_info  \
# 0       0.0        NaN          NaN  <subject_info | his_id: X, last_name: >
# 1       0.0        NaN          NaN  <subject_info | his_id: X, last_name: >
# 2       0.0        NaN          NaN  <subject_info | his_id: X, last_name: >
# 3       0.0        NaN          NaN  <subject_info | his_id: X, last_name: >
# 4       0.0        NaN          NaN  <subject_info | his_id: X, last_name: >
#
#                                          annotations  \
# 0               [np.str_('33024'), np.str_('33025')]
# 1  [np.str_('33024'), np.str_('33025'), np.str_('...
# 2  [np.str_('33024'), np.str_('33025'), np.str_('...
# 3  [np.str_('33024'), np.str_('33025'), np.str_('...
# 4  [np.str_('33024'), np.str_('33025'), np.str_('...
#
#                                   annotation_summary  file_size_mb
# 0  {np.str_('33025'): np.int64(1), np.str_('33024...         27.46
# 1  {np.str_('33025'): np.int64(1), np.str_('33029...         27.74
# 2  {np.str_('33025'): np.int64(1), np.str_('33029...         27.74
# 3  {np.str_('33025'): np.int64(1), np.str_('33029...         27.74
# 4  {np.str_('33025'): np.int64(1), np.str_('33029...         27.74

# %% [markdown]
# ### **1) Show problematic files (duration dev > 1s, missing annotation, duplicates)**

# %%
# extract basename and numeric id
df['basename'] = df['file'].apply(lambda x: x.split('\\')[-1])
df['id'] = df['basename'].str.extract(r'ID(\d+)').astype(float).astype('Int64')

# missing IDs (0..43)
expected = set(range(44))
present_ids = set(df['id'].dropna().astype(int))
missing_ids = sorted(expected - present_ids)
print('Missing IDs:', missing_ids)

# duplicates
dups = df['id'][df['id'].duplicated(keep=False)]
print('Duplicate ID entries (check these files):')
print(df[df['id'].isin(dups)][['basename','file']])
# Out:
# Missing IDs: [12, 17, 28, 29, 32, 34, 36, 42]
# Duplicate ID entries (check these files):
#       basename                      file
# 6  ID15(1).gdf  Pain-Dataset\ID15(1).gdf
# 7     ID15.gdf     Pain-Dataset\ID15.gdf

# %%
# duration deviations (more than 1s)
df['duration_dev_sec'] = df['duration_sec'] - 600.0
bad_dur = df[df['duration_dev_sec'].abs() > 1.0][['basename','duration_sec','duration_dev_sec','n_samples']]
print('Files with duration deviating > 1s from 600s:')
print(bad_dur.to_string(index=False))

print('-'*40,'\n')

# files with unusual annotations
print('Distinct annotation sets and counts:')
print(df['annotations'].value_counts())
# Out:
# Files with duration deviating > 1s from 600s:
#    basename  duration_sec  duration_dev_sec  n_samples
#     ID1.gdf       605.824             5.824     151456
#    ID10.gdf       605.952             5.952     151488
#    ID11.gdf       605.824             5.824     151456
#    ID13.gdf       605.824             5.824     151456
#    ID14.gdf       605.824             5.824     151456
# ID15(1).gdf       605.824             5.824     151456
#    ID15.gdf       605.824             5.824     151456
#    ID16.gdf       605.824             5.824     151456
#    ID18.gdf       605.824             5.824     151456
#    ID19.gdf       605.824             5.824     151456
#     ID2.gdf       605.824             5.824     151456
#    ID20.gdf       605.824             5.824     151456
#    ID21.gdf       605.824             5.824     151456
#    ID22.gdf       605.824             5.824     151456
#    ID23.gdf       605.952             5.952     151488
#    ID24.gdf       605.952             5.952     151488
#    ID25.gdf       605.824             5.824     151456
#    ID27.gdf       605.952             5.952     151488
#     ID3.gdf       605.824             5.824     151456
#    ID30.gdf       605.824             5.824     151456
#    ID31.gdf       605.824             5.824     151456
#    ID33.gdf       605.824             5.824     151456
#    ID35.gdf       605.824             5.824     151456
#    ID37.gdf       605.824             5.824     151456
#    ID38.gdf       605.824             5.824     151456
#    ID39.gdf       605.824             5.824     151456
#     ID4.gdf       605.824             5.824     151456
#    ID40.gdf       605.824             5.824     151456
#    ID41.gdf       605.824             5.824     151456
#    ID43.gdf       605.824             5.824     151456
#     ID5.gdf       605.824             5.824     151456
#     ID6.gdf       605.824             5.824     151456
#     ID7.gdf       605.824             5.824     151456
#     ID8.gdf       605.824             5.824     151456
#     ID9.gdf       605.952             5.952     151488
# ----------------------------------------
#
# Distinct annotation sets and counts:
# annotations
# ['33024' '33025' '33029']    35
# ['33024' '33025']             2
# Name: count, dtype: int64

# %% [markdown]
# ### **2) Inspect annotations inside a given GDF file to get event times (run per-file)**

# %%
import mne
from pathlib import Path
f = Path('Pain-Dataset') / 'ID1.gdf'   # change filename as needed
raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
print('Sampling rate:', raw.info['sfreq'])
print('Channels:', raw.info['ch_names'][:6], '...')

# Show annotations (onset, duration, description)
ann = raw.annotations
print('Annotations object:', ann)
if ann is not None:
    for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
        print(f'onset(s)={onset:.3f}, dur={duration:.3f}, desc={desc}')
else:
    print('No annotations found in this file.')
# Out:
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029

# %%
# For each file in the dataset 

import mne
from pathlib import Path

# Path to the folder containing .gdf files
folder_path = Path('Pain-Dataset')

# Loop through all .gdf files in the folder
for f in folder_path.glob('*.gdf'):
    print(f"Processing file: {f.name}")
    
    # Read the raw EEG data
    raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
    
    # Print the sampling rate and first 6 channel names
    print('Sampling rate:', raw.info['sfreq'])
    print('Channels:', raw.info['ch_names'][:6], '...')
    
    # Show annotations (onset, duration, description)
    ann = raw.annotations
    print('Annotations object:', ann)
    
    if ann is not None:
        for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
            print(f'onset(s)={onset:.3f}, dur={duration:.3f}, desc={desc}')
    else:
        print('No annotations found in this file.')
    
    print('-' * 40)  # Print a separator between files
# Out:
# Processing file: ID0.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 2 segments: 33024 (1), 33025 (1)>
# onset(s)=0.000, dur=0.004, desc=33024
# onset(s)=300.000, dur=0.004, desc=33025
# ----------------------------------------
# Processing file: ID1.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID10.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID11.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID13.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID14.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID15(1).gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID15.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID16.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID18.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID19.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID2.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID20.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID21.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID22.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID23.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID24.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID25.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID26.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 2 segments: 33024 (1), 33025 (1)>
# onset(s)=0.000, dur=0.004, desc=33024
# onset(s)=300.000, dur=0.004, desc=33025
# ----------------------------------------
# Processing file: ID27.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID3.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID30.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID31.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID33.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID35.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID37.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID38.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID39.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID4.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID40.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID41.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID43.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID5.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID6.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID7.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID8.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------
# Processing file: ID9.gdf
# Sampling rate: 250.0
# Channels: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4'] ...
# Annotations object: <Annotations | 3 segments: 33024 (1), 33025 (1), 33029 (1)>
# onset(s)=5.000, dur=0.004, desc=33024
# onset(s)=305.000, dur=0.004, desc=33025
# onset(s)=605.000, dur=0.004, desc=33029
# ----------------------------------------

# %%
import mne
import pandas as pd
from pathlib import Path

DATA_DIR = Path('Pain-Dataset')

summary_rows = []

for f in sorted(DATA_DIR.glob('*.gdf')):
    try:
        raw = mne.io.read_raw_gdf(str(f), preload=False, verbose='ERROR')
        ann = raw.annotations
        sampling_rate = raw.info['sfreq']
        ch_names = ','.join(raw.info['ch_names'])
        
        if ann is not None and len(ann) > 0:
            for onset, duration, desc in zip(ann.onset, ann.duration, ann.description):
                summary_rows.append({
                    'file': f.name,
                    'sampling_rate': sampling_rate,
                    'num_channels': len(raw.info['ch_names']),
                    'onset_s': round(onset, 3),
                    'duration_s': round(duration, 3),
                    'event_code': desc
                })
        else:
            summary_rows.append({
                'file': f.name,
                'sampling_rate': sampling_rate,
                'num_channels': len(raw.info['ch_names']),
                'onset_s': None,
                'duration_s': None,
                'event_code': 'None'
            })
    except Exception as e:
        print(f"Error reading {f.name}: {e}")

# Create DataFrame
df_ann = pd.DataFrame(summary_rows)

# Save for later
df_ann.to_csv('annotations_summary.csv', index=False)

print("✅ Annotation summary saved as annotations_summary.csv")
display(df_ann.head())
# Out:
# ✅ Annotation summary saved as annotations_summary.csv
#       file  sampling_rate  num_channels  onset_s  duration_s event_code
# 0  ID0.gdf          250.0            24      0.0       0.004      33024
# 1  ID0.gdf          250.0            24    300.0       0.004      33025
# 2  ID1.gdf          250.0            24      5.0       0.004      33024
# 3  ID1.gdf          250.0            24    305.0       0.004      33025
# 4  ID1.gdf          250.0            24    605.0       0.004      33029

# %% [markdown]
# ### **Save the Data into EYE OPEN(EO) and EYE CLOSE(EC) Segments and save it for further use**

# %%
'''
# here we dont take the ID0, ID26 special cases into consideration ...

import mne
from pathlib import Path
import numpy as np

base = Path('Pain-Dataset')
save_dir = Path('Segments')
save_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]
    
    # --- Find event onsets safely ---
    codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
    start1 = codes.get('33024', 0.0)      # EO start
    start2 = codes.get('33025', start1 + 300.0)  # EC start
    end    = codes.get('33029', start2 + 300.0)  # recording end or EC end fallback

    # --- Fix missing/extra durations ---
    # EO desired = [5s, 305s], EC = [305s, 605s]
    eo_start = max(start1, 5.0)
    eo_end   = eo_start + 300.0
    ec_start = eo_end
    ec_end   = ec_start + 300.0

    # Clamp within available recording length
    eo_end = min(eo_end, total_dur)
    ec_end = min(ec_end, total_dur)

    # Round down to nearest multiple of 5
    def round_down_5(x):
        return np.floor(x / 5) * 5

    eo_start = round_down_5(eo_start)
    eo_end   = round_down_5(eo_end)
    ec_start = round_down_5(ec_start)
    ec_end   = round_down_5(ec_end)

    # Skip if too short (<5s)
    if ec_end - ec_start < 5 or eo_end - eo_start < 5:
        print(f"⚠️ Skipped (too short): {f.name}")
        continue

    # --- Crop segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

    # --- Save both segments ---
    eo.save(save_dir / f"{f.stem}_EO_raw.fif", overwrite=True)
    ec.save(save_dir / f"{f.stem}_EC_raw.fif", overwrite=True)

    # Optionally save arrays
    np.save(save_dir / f"{f.stem}_EO.npy", eo.get_data())
    np.save(save_dir / f"{f.stem}_EC.npy", ec.get_data())

    print(f"✅ EO: {eo_start:.1f}-{eo_end:.1f}s | EC: {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n🎯 Segmentation complete: all EO & EC files saved cleanly.")


'''

# %%
"""
# Here alll files are stored in same folder ...

import mne
from pathlib import Path
import numpy as np

base = Path('Pain-Dataset')
save_dir = Path('Segments')
save_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]

    # --- Handle ID0 and ID26 separately ---
    if 'ID0' in f.name or 'ID26' in f.name:
        eo_start, eo_end = 0.0, 300.0
        ec_start = eo_end
        ec_end = np.floor(total_dur / 5) * 5  # round down to multiple of 5
        print(f"⚙️ Using fixed timing for {f.name}")
    else:
        # --- Normal case: derive timings from annotations ---
        codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
        start1 = codes.get('33024', 0.0)       # EO start
        start2 = codes.get('33025', start1 + 300.0)  # EC start
        end = codes.get('33029', start2 + 300.0)     # End

        # EO desired = [5s, 305s], EC = [305s, 605s]
        eo_start = max(start1, 5.0)
        eo_end = eo_start + 300.0
        ec_start = eo_end
        ec_end = ec_start + 300.0

        # Clamp within total duration
        eo_end = min(eo_end, total_dur)
        ec_end = min(ec_end, total_dur)

        # Round to nearest multiple of 5
        def round_down_5(x):
            return np.floor(x / 5) * 5

        eo_start = round_down_5(eo_start)
        eo_end = round_down_5(eo_end)
        ec_start = round_down_5(ec_start)
        ec_end = round_down_5(ec_end)

        # Skip if segment too short
        if ec_end - ec_start < 5 or eo_end - eo_start < 5:
            print(f"⚠️ Skipped (too short): {f.name}")
            continue

    # --- Crop both segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

    # --- Save both segments ---
    eo.save(save_dir / f"{f.stem}_EO_raw.fif", overwrite=True)
    ec.save(save_dir / f"{f.stem}_EC_raw.fif", overwrite=True)

    np.save(save_dir / f"{f.stem}_EO.npy", eo.get_data())
    np.save(save_dir / f"{f.stem}_EC.npy", ec.get_data())

    print(f"✅ EO: {eo_start:.1f}-{eo_end:.1f}s | EC: {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n🎯 Segmentation complete: all EO & EC files saved cleanly.")


# the above is the helper function and this is for saving the segments ...

import mne
import numpy as np
from pathlib import Path


# directory containing your processed files
DATA_DIR = Path("Segments")  
SAMPLING_RATE = 250  # Hz
EXPECTED_SEGMENT_SEC = [300, 600]  # 5 min or 10 min possible

print(f"\nChecking all .fif and .npy files in: {DATA_DIR}\n{'='*80}")

for file in sorted(DATA_DIR.glob("*")):
    if file.suffix == ".fif":
        raw = mne.io.read_raw_fif(file, preload=False, verbose="ERROR")
        n_channels = len(raw.ch_names)
        n_samples = raw.n_times
        duration_sec = n_samples / SAMPLING_RATE

        # Status check
        status = (
            "✅ Exact 5 min"
            if abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[FIF] {file.name}")
        print(f"   Channels: {n_channels}, Samples: {n_samples}, Duration: {duration_sec:.2f}s → {status}")

    elif file.suffix == ".npy":
        data = np.load(file)
        if data.ndim == 2:
            n_channels, n_samples = data.shape
        elif data.ndim == 3:
            n_channels, n_samples, _ = data.shape
        else:
            n_channels, n_samples = "?", "?"

        duration_sec = n_samples / SAMPLING_RATE if isinstance(n_samples, int) else "?"
        status = (
            "✅ Exact 5 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[NPY] {file.name}")
        print(f"   Shape: {data.shape}, Duration: {duration_sec}s → {status}")

print("\nCheck complete ✅\n")


"""

# %%
import mne
from pathlib import Path
import numpy as np

base = Path('Pain-Dataset')
save_dir = Path('Segments')
save_dir.mkdir(exist_ok=True)

# --- Create subfolders ---
eo_dir = save_dir / 'EO'
ec_dir = save_dir / 'EC'
eo_dir.mkdir(exist_ok=True)
ec_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]

    # --- Handle ID0 and ID26 separately ---
    if 'ID0' in f.name or 'ID26' in f.name:
        eo_start, eo_end = 0.0, 300.0
        ec_start = eo_end
        ec_end = np.floor(total_dur / 5) * 5  # round down to multiple of 5
        print(f"⚙️ Using fixed timing for {f.name}")
    else:
        # --- Normal case: derive timings from annotations ---
        codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
        start1 = codes.get('33024', 0.0)        # EO start
        start2 = codes.get('33025', start1 + 300.0)  # EC start
        end = codes.get('33029', start2 + 300.0)     # End

        # EO desired = [5s, 305s], EC = [305s, 605s]
        eo_start = max(start1, 5.0)
        eo_end = eo_start + 300.0
        ec_start = eo_end
        ec_end = ec_start + 300.0

        # Clamp within total duration
        eo_end = min(eo_end, total_dur)
        ec_end = min(ec_end, total_dur)

        # Round to nearest multiple of 5
        def round_down_5(x):
            return np.floor(x / 5) * 5

        eo_start = round_down_5(eo_start)
        eo_end = round_down_5(eo_end)
        ec_start = round_down_5(ec_start)
        ec_end = round_down_5(ec_end)

        # Skip if segment too short
        if ec_end - ec_start < 5 or eo_end - eo_start < 5:
            print(f"⚠️ Skipped (too short): {f.name}")
            continue

    # --- Check for overlap or repetition ---
    if np.isclose(eo_end, ec_start):
        print(f"⚠️ Boundary overlap at {eo_end:.1f}s for {f.name}")

    # --- Crop both segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

    # --- Save both segments in separate subfolders ---
    eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
    ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)

    np.save(eo_dir / f"{f.stem}_EO.npy", eo.get_data())
    np.save(ec_dir / f"{f.stem}_EC.npy", ec.get_data())

    print(f"✅ EO: {eo_start:.1f}-{eo_end:.1f}s | EC: {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n🎯 Segmentation complete: EO & EC files saved in respective subfolders.")
# Out:
# 📁 Processing ID0.gdf
# ⚙️ Using fixed timing for ID0.gdf
# ⚠️ Boundary overlap at 300.0s for ID0.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID0_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID0_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID0_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID0_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID0_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID0_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 0.0-300.0s | EC: 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID1.gdf
# ⚠️ Boundary overlap at 305.0s for ID1.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID1_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID1_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID1_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID1_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID10.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID1_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID1_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID10.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID10_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID10_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID10_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID10_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID10_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID10_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID11.gdf
# ⚠️ Boundary overlap at 305.0s for ID11.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID11_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID11_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID11_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID11_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID11_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID11_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID13.gdf
# ⚠️ Boundary overlap at 305.0s for ID13.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID13_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID13_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID13_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID13_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID14.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID13_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID13_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID14.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID14_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID14_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID14_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID14_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID14_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID14_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID15(1).gdf
# ⚠️ Boundary overlap at 305.0s for ID15(1).gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15(1)_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15(1)_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15(1)_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15(1)_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15(1)_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15(1)_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID15.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID15_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID15_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID16.gdf
# ⚠️ Boundary overlap at 305.0s for ID16.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID16_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID16_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID16_EC.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID16_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID16_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID16_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID18.gdf
# ⚠️ Boundary overlap at 305.0s for ID18.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID18_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID18_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID18_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID18_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID18_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID18_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID19.gdf
# ⚠️ Boundary overlap at 305.0s for ID19.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID19_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID19_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID19_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID19_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID19_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID19_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID2.gdf
# ⚠️ Boundary overlap at 305.0s for ID2.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID2_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID2_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID2_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID2_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID20.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID2_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID2_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID20.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID20_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID20_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID20_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID20_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID20_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID20_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID21.gdf
# ⚠️ Boundary overlap at 305.0s for ID21.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID21_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID21_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID21_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID21_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID22.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID21_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID21_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID22.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID22_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID22_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID22_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID22_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID22_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID22_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID23.gdf
# ⚠️ Boundary overlap at 305.0s for ID23.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID23_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID23_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID23_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID23_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID23_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID23_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID24.gdf
# ⚠️ Boundary overlap at 305.0s for ID24.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID24_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID24_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID24_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID24_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID24_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID24_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID25.gdf
# ⚠️ Boundary overlap at 305.0s for ID25.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID25_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID25_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID25_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID25_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID26.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID25_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID25_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚙️ Using fixed timing for ID26.gdf
# ⚠️ Boundary overlap at 300.0s for ID26.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID26_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID26_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID26_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID26_EC.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID26_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID26_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# [done]
# ✅ EO: 0.0-300.0s | EC: 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID27.gdf
# ⚠️ Boundary overlap at 305.0s for ID27.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID27_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID27_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID27_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID27_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID3.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID27_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID27_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID3.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID3_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID3_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID3_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID3_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID3_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID3_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID30.gdf
# ⚠️ Boundary overlap at 305.0s for ID30.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID30_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID30_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID30_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID30_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID31.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID30_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID30_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID31.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID31_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID31_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID31_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID31_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID31_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID31_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID33.gdf
# ⚠️ Boundary overlap at 305.0s for ID33.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID33_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID33_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID33_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID33_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID35.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID33_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID33_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID35.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID35_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID35_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID35_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID35_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID35_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID35_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID37.gdf
# ⚠️ Boundary overlap at 305.0s for ID37.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID37_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID37_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID37_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID37_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID37_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID37_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID38.gdf
# ⚠️ Boundary overlap at 305.0s for ID38.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID38_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID38_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID38_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID38_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID39.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID38_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID38_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID39.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID39_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID39_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID39_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID39_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID39_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID39_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID4.gdf
# ⚠️ Boundary overlap at 305.0s for ID4.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID4_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID4_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID4_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID4_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID40.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID4_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID4_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ⚠️ Boundary overlap at 305.0s for ID40.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID40_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID40_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID40_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID40_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID40_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID40_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID41.gdf
# ⚠️ Boundary overlap at 305.0s for ID41.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID41_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID41_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID41_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID41_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID41_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID41_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID43.gdf
# ⚠️ Boundary overlap at 305.0s for ID43.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID43_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID43_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID43_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID43_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID43_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID43_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID5.gdf
# ⚠️ Boundary overlap at 305.0s for ID5.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID5_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID5_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID5_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID5_EC.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID5_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID5_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID6.gdf
# ⚠️ Boundary overlap at 305.0s for ID6.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID6_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID6_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID6_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID6_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID6_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID6_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID7.gdf
# ⚠️ Boundary overlap at 305.0s for ID7.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID7_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID7_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID7_EC.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID7_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID7_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID7_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# 📁 Processing ID8.gdf
# ⚠️ Boundary overlap at 305.0s for ID8.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID8_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID8_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID8_EC.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID8_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID8_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID8_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID9.gdf
# ⚠️ Boundary overlap at 305.0s for ID9.gdf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID9_EO.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID9_EO.fif
# [done]
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID9_EC.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:68: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO\ID9_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eo.save(eo_dir / f"{f.stem}_EO.fif", overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\975917809.py:69: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID9_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   ec.save(ec_dir / f"{f.stem}_EC.fif", overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC\ID9_EC.fif
# [done]
# ✅ EO: 5.0-305.0s | EC: 305.0-605.0s | Total duration: 605.9s
#
# 🎯 Segmentation complete: EO & EC files saved in respective subfolders.

# %%
import os

# Base folder
base_dir = "Segments"

# Subfolders
subfolders = ["EO", "EC"]

# Loop through each subfolder and count file types
for sub in subfolders:
    folder_path = os.path.join(base_dir, sub)
    
    # Counters for this folder
    count_fif = 0
    count_npy = 0
    
    for file in os.listdir(folder_path):
        if file.endswith(".fif"):
            count_fif += 1
        elif file.endswith(".npy"):
            count_npy += 1
    
    total_files = count_fif + count_npy
    print(f"\n{sub} Folder:")
    print(f"  Total files: {total_files}")
    print(f"  .fif files: {count_fif}")
    print(f"  .npy files: {count_npy}")
# Out:
# EO Folder:
#   Total files: 74
#   .fif files: 37
#   .npy files: 37
#
# EC Folder:
#   Total files: 74
#   .fif files: 37
#   .npy files: 37

# %%
# Information about .fif files in each subfolder

import os
import mne

# Base folder
base_dir = "Segments"
subfolders = ["EO", "EC"]

for sub in subfolders:
    folder_path = os.path.join(base_dir, sub)
    print(f"\n=== {sub} Folder ===")
    
    # Loop through all files in the folder
    for file in os.listdir(folder_path):
        if file.endswith(".fif"):
            file_path = os.path.join(folder_path, file)
            
            # Read the EEG data (without loading raw data into memory)
            raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
            
            # Extract info
            n_channels = len(raw.info['ch_names'])
            ch_names = raw.info['ch_names']
            sfreq = raw.info['sfreq']
            n_times = raw.n_times
            duration = n_times / sfreq
            
            print(f"\nFile: {file}")
            print(f"  Channels: {n_channels}")
            print(f"  Channel names: {ch_names}")
            print(f"  Sampling frequency: {sfreq} Hz")
            print(f"  Time points: {n_times}")
            print(f"  Duration: {duration:.2f} seconds")

            print("-" * 50)
# Out:
# === EO Folder ===
#
# File: ID0_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID10_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID0_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID10_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID11_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID11_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID13_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID14_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID15(1)_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID13_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID14_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID15(1)_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID15_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID15_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID16_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID18_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID19_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID16_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID18_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID19_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID1_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID1_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID20_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID21_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID22_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID20_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID21_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID22_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID23_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID23_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID24_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID25_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID26_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID27_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID24_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID25_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID26_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID27_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID2_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID2_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID30_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID31_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID33_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID30_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID31_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID33_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID35_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID35_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID37_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID38_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID37_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID38_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID39_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID39_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID3_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID40_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID41_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID43_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID3_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID40_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID41_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID43_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID4_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID4_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID5_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID6_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID7_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID8_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID9_EO.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# === EC Folder ===
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID5_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID6_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID7_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID8_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EO\ID9_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID0_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID0_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 73751
#   Duration: 295.00 seconds
#
# File: ID10_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID11_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID13_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID10_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID11_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID13_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID14_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID14_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID15(1)_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID15_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID16_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID15(1)_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID15_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID16_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID18_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID18_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID19_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID1_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID20_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID19_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID1_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID20_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID21_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID21_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID22_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID23_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID24_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID25_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID22_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID23_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID24_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID25_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID26_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID26_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 73751
#   Duration: 295.00 seconds
#
# File: ID27_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID2_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID30_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID27_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID2_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID30_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID31_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID31_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID33_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID35_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID37_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID33_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID35_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID37_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID38_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID38_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID39_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID3_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID40_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID39_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID3_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID40_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID41_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID41_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID43_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID4_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID5_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID6_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID43_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID4_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID5_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID6_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID7_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID7_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID8_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
#
# File: ID9_EC.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 75001
#   Duration: 300.00 seconds
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID8_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\407421741.py:18: RuntimeWarning: This filename (Segments\EC\ID9_EC.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)

# %%
# inofrmation about .npy files in each subfolder

import os
import numpy as np

base_dir = "Segments"
subfolders = ["EO", "EC"]

for sub in subfolders:
    folder_path = os.path.join(base_dir, sub)
    print(f"\n=== {sub} Folder ===")
    
    for file in os.listdir(folder_path):
        if file.endswith(".npy"):
            file_path = os.path.join(folder_path, file)
            
            data = np.load(file_path)
            
            print(f"\nFile: {file}")
            print(f"  Shape: {data.shape}")
            print(f"  Data type: {data.dtype}")
            
            if len(data.shape) == 2:
                print(f"  -> Likely {data.shape[0]} channels × {data.shape[1]} samples")
# Out:
# === EO Folder ===
#
# File: ID0_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID10_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID11_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID13_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID14_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID15(1)_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID15_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID16_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID18_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID19_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID1_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID20_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID21_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID22_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID23_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID24_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID25_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID26_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID27_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID2_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID30_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID31_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID33_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID35_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID37_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID38_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID39_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID3_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID40_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID41_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID43_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID4_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID5_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID6_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID7_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID8_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID9_EO.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# === EC Folder ===
#
# File: ID0_EC.npy
#   Shape: (24, 73751)
#   Data type: float64
#   -> Likely 24 channels × 73751 samples
#
# File: ID10_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID11_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID13_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID14_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID15(1)_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID15_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID16_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID18_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID19_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID1_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID20_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID21_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID22_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID23_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID24_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID25_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID26_EC.npy
#   Shape: (24, 73751)
#   Data type: float64
#   -> Likely 24 channels × 73751 samples
#
# File: ID27_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID2_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID30_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID31_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID33_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID35_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID37_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID38_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID39_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID3_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID40_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID41_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID43_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID4_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID5_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID6_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID7_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID8_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples
#
# File: ID9_EC.npy
#   Shape: (24, 75001)
#   Data type: float64
#   -> Likely 24 channels × 75001 samples

# %% [markdown]
# ### **Run ICA for EO Component**

# %%
# method 1 (this is for single file No need to save it in folder ) .

import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define paths ---
example_file = Path("Segments\EO\ID0_EO.fif")  # actual file path


# --- Load .fif file ---
raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

# --- Check basic info ---
print(raw_example.info)

# --- Rename FP1, FP2 if needed ---
rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}

if rename_dict:
    print("Renaming channels:", rename_dict)
    raw_example.rename_channels(rename_dict)

# --- Set standard montage ---
try:
    raw_example.set_montage('standard_1020', on_missing='ignore')
    print(" Montage set successfully with 'standard_1020'")
except Exception as e:
    print(" Montage assignment issue:", e)



# --- Run ICA ---
ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
ica.fit(raw_example)

# --- Plot ICA components ---
ica.plot_components()  # Shows interactively


print(f"✅ ICA completed  for {example_file.name}")
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: FP1, FP2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T7, T8, P7, ...
#  chs: 24 EEG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 24
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: X>
# >
# Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
#  Montage set successfully with 'standard_1020'
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\642028295.py:35: RuntimeWarning: The data has not been high-pass filtered. For good ICA performance, it should be high-pass filtered (e.g., with a 1.0 Hz lower bound) before fitting ICA.
#   ica.fit(raw_example)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# <MNEFigure size 975x731.5 with 15 Axes>
# ✅ ICA completed  for ID0_EO.fif

# %%
# method 2 ( this is for single file No need to save it in folder ) .

import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define paths ---
example_file = Path("Segments\EO\ID0_EO.fif")  # actual file path


# --- Load .fif file ---
raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

# --- Check basic info ---
print(raw_example.info)

# --- Rename FP1, FP2 if needed ---
rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}

if rename_dict:
    print("Renaming channels:", rename_dict)
    raw_example.rename_channels(rename_dict)

# --- Set standard montage ---
try:
    raw_example.set_montage('standard_1020', on_missing='ignore')
    print(" Montage set successfully with 'standard_1020'")
except Exception as e:
    print(" Montage assignment issue:", e)


# --- Filter and reference before ICA ---
raw_example.pick_types(eeg=True)
raw_example.set_eeg_reference('average', projection=True)
raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

# --- Run ICA ---
ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
ica.fit(raw_ica)

# --- Plot ICA components ---
ica.plot_components()  # Shows interactively



print(f"✅ ICA completed for {example_file.name}")
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: FP1, FP2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T7, T8, P7, ...
#  chs: 24 EEG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 24
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: X>
# >
# Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
#  Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# <MNEFigure size 975x731.5 with 15 Axes>
# ✅ ICA completed for ID0_EO.fif

# %% [markdown]
# ---
#
# ## 🔍 Overview of the Two Methods
#
# | Step                     | Method 1             | Method 2                              |
# | ------------------------ | -------------------- | ------------------------------------- |
# | Preprocessing before ICA | None                 | Filtering + Re-referencing            |
# | ICA fitting              | Directly on raw data | On filtered, averaged-referenced data |
#
# ---
#
# ## ⚙️ What’s Happening in Each Method
#
# ### **Method 1:**
#
# ```python
# ica.fit(raw_example)
# ```
#
# You are fitting ICA directly to the **unfiltered, raw EEG** signal (as loaded from `.fif`).
#
# **Problems:**
#
# 1. **DC offsets & slow drifts** — Unfiltered EEG data contains very low-frequency noise (including drift and DC offsets). ICA is extremely sensitive to these and can’t separate sources properly.
# 2. **Reference issue** — ICA assumes data is **zero-mean and properly referenced**. If the EEG isn’t average-referenced, ICA might pick up reference-related artifacts as components.
# 3. **Extra channels** — If you don’t select only EEG channels, ICA might also see stim/ECG/EOG channels, confusing the decomposition.
# 4. **Scaling** — Large low-frequency variance dominates, causing ICA to explain mostly that instead of meaningful independent sources.
#
# Hence, the components you get (and plots) look strange or uninformative.
#
# ---
#
# ### **Method 2:**
#
# ```python
# raw_example.pick_types(eeg=True)
# raw_example.set_eeg_reference('average', projection=True)
# raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)
# ica.fit(raw_ica)
# ```
#
# Here you’re doing things **the correct MNE way**:
#
# 1. ✅ **Selecting EEG channels only**
#    → Removes irrelevant signals like triggers or EOG that ICA shouldn’t model.
#
# 2. ✅ **Setting average reference**
#    → Ensures zero-mean data; ICA requires a proper reference.
#
# 3. ✅ **High-pass filtering (1 Hz)**
#    → Removes slow drifts and DC offsets that dominate the variance.
#    → ICA then focuses on physiologically meaningful components (eye blinks, muscle, alpha, etc.).
#
# These preprocessing steps make ICA **converge better**, produce **interpretable components**, and hence the ICA plots look “proper.”
#
# ---
#
# ## 🧠 TL;DR Summary
#
# | Aspect                | Method 1                | Method 2                   |
# | --------------------- | ----------------------- | -------------------------- |
# | Filtering             | ❌ None                  | ✅ High-pass at 1 Hz        |
# | Referencing           | ❌ Raw reference         | ✅ Average reference        |
# | Channel selection     | ❌ All channels          | ✅ EEG only                 |
# | ICA convergence       | Poor                    | Stable                     |
# | ICA component quality | Unreliable              | Physiologically meaningful |
# | Plot appearance       | Strange / blank / noisy | Proper scalp maps          |
#
# ---
#
# ✅ **Conclusion:**
# **Method 2 is correct** for running ICA on EEG data.
# **Method 1 skips crucial preprocessing** (filtering + referencing), so ICA doesn’t behave well and the plots look wrong.
#
# ---

# %%
# method 2 ( this is for single file No need to save it in folder ) .

import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define paths ---
example_file = Path("Segments\EO\ID0_EO.fif")  # actual file path


# --- Load .fif file ---
raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

# --- Check basic info ---
print(raw_example.info)

# --- Rename FP1, FP2 if needed ---
rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}

if rename_dict:
    print("Renaming channels:", rename_dict)
    raw_example.rename_channels(rename_dict)

# --- Set standard montage ---
try:
    raw_example.set_montage('standard_1020', on_missing='ignore')
    print(" Montage set successfully with 'standard_1020'")
except Exception as e:
    print(" Montage assignment issue:", e)


# --- Filter and reference before ICA ---
raw_example.pick_types(eeg=True)
raw_example.set_eeg_reference('average', projection=True)
raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

# --- Run ICA ---
ica = mne.preprocessing.ICA(n_components=24, random_state=97, max_iter='auto')
ica.fit(raw_ica)

# --- Plot ICA components ---
ica.plot_components()  # Shows interactively



print(f"✅ ICA completed for {example_file.name}")
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: FP1, FP2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T7, T8, P7, ...
#  chs: 24 EEG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 24
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: X>
# >
# Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
#  Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 24 components
# Fitting ICA took 1.8s.
# <MNEFigure size 975x967 with 20 Axes>
# <MNEFigure size 780x260.5 with 4 Axes>
# ✅ ICA completed for ID0_EO.fif

# %% [markdown]
# ### **For all EO files**

# %%
import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define input/output paths ---
eo_dir = Path("Segments/EO")               # Folder with EO .fif files
OUTPUT_DIR = Path("pain_dataset_outputs")
output_subdir = OUTPUT_DIR / "EO-ICA-Components"  # New subfolder for ICA images 

output_subdir.mkdir(parents=True, exist_ok=True)

print(f"\n📁 Searching for EO files in: {eo_dir.resolve()}")

# --- Iterate through all EO .fif files ---
for example_file in sorted(eo_dir.glob("*.fif")):
    print(f"\n⚙️ Processing file: {example_file.name}")

    # --- Load .fif file ---
    raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

    # --- Rename FP1, FP2 if needed ---
    rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}

    if rename_dict:
        print("🔤 Renaming channels:", rename_dict)
        raw_example.rename_channels(rename_dict)

    # --- Set standard montage ---
    try:
        raw_example.set_montage('standard_1020', on_missing='ignore')
        print("🧠 Montage set successfully with 'standard_1020'")
    except Exception as e:
        print(f"⚠️ Montage assignment issue: {e}")

    # --- Filter and reference before ICA ---
    raw_example.pick_types(eeg=True)
    raw_example.set_eeg_reference('average', projection=True)
    raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

    # --- Run ICA ---
    ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
    ica.fit(raw_ica)

    # --- Plot ICA components (optional interactive view) ---
    # ica.plot_components()  # this show pictures in terminal 

    # --- Save ICA component grid image ---
    fig = ica.plot_components(show=False)
    save_path = output_subdir / f"{example_file.stem}_ICA_Components_EO.png"
    fig.savefig(save_path, dpi=150)
    plt.close(fig)

    print(f"✅ ICA completed and image saved: {save_path.name}")

print(f"\n🎯 All EO ICA component plots saved in: {output_subdir.resolve()}")
# Out:
# 📁 Searching for EO files in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO
#
# ⚙️ Processing file: ID0_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID0_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID10_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID10_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID11_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID11_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID13_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID13_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID14_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID14_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID15(1)_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID15(1)_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID15_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID15_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID16_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# ✅ ICA completed and image saved: ID16_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID18_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID18_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID19_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID19_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID1_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID1_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID20_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID20_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID21_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID21_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID22_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID22_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID23_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID23_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID24_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID24_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID25_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID25_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID26_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 2.6s.
# ✅ ICA completed and image saved: ID26_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID27_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.4s.
# ✅ ICA completed and image saved: ID27_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID2_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID2_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID30_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID30_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID31_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID31_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID33_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID33_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID35_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID35_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID37_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID37_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID38_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID38_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID39_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.5s.
# ✅ ICA completed and image saved: ID39_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID3_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID3_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID40_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.3s.
# ✅ ICA completed and image saved: ID40_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID41_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID41_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID43_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID43_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID4_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID4_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID5_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID5_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID6_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID6_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID7_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID7_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID8_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID8_EO_ICA_Components_EO.png
#
# ⚙️ Processing file: ID9_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\687997835.py:42: RuntimeWarning: Using n_components=15 (resulting in n_components_=15) may lead to an unstable mixing matrix estimation because the ratio between the largest (24) and smallest (9.5e-06) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 9
#   ica.fit(raw_ica)
# ✅ ICA completed and image saved: ID9_EO_ICA_Components_EO.png
#
# 🎯 All EO ICA component plots saved in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\pain_dataset_outputs\EO-ICA-Components

# %%
import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define input/output paths ---
eo_dir = Path("Segments/EO")               # Folder with EO .fif files
OUTPUT_DIR = Path("pain_dataset_outputs")
output_subdir = OUTPUT_DIR / "EO-ICA-Components_V2"  # New subfolder for ICA images 

output_subdir.mkdir(parents=True, exist_ok=True)

print(f"\n📁 Searching for EO files in: {eo_dir.resolve()}")

# --- Iterate through all EO .fif files ---
for example_file in sorted(eo_dir.glob("*.fif")):
    print(f"\n⚙️ Processing file: {example_file.name}")

    # --- Load .fif file ---
    raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

    # --- Rename FP1, FP2 if needed ---
    rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}
    if rename_dict:
        print("🔤 Renaming channels:", rename_dict)
        raw_example.rename_channels(rename_dict)

    # --- Set standard montage ---
    try:
        raw_example.set_montage('standard_1020', on_missing='ignore')
        print("🧠 Montage set successfully with 'standard_1020'")
    except Exception as e:
        print(f"⚠️ Montage assignment issue: {e}")

    # --- Filter and reference before ICA ---
    raw_example.pick_types(eeg=True)
    raw_example.set_eeg_reference('average', projection=True)
    raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

    # --- Run ICA ---
    ica = mne.preprocessing.ICA(n_components=10, random_state=97, max_iter='auto') # plot only 5 components
    ica.fit(raw_ica)

    # --- Plot ICA components (optional interactive view) ---
    # ica.plot_components()  #  show pictures in terminal

    # --- Save ICA component grid image ---
    fig = ica.plot_components(show=False)
    save_path = output_subdir / f"{example_file.stem}_ICA_Components_EO_V2.png"
    fig.savefig(save_path, dpi=150)
    plt.close(fig)

    print(f"✅ ICA completed and image saved: {save_path.name}")

print(f"\n🎯 All EO ICA component plots saved in: {output_subdir.resolve()}")
# Out:
# 📁 Searching for EO files in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EO
#
# ⚙️ Processing file: ID0_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.3s.
# ✅ ICA completed and image saved: ID0_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID10_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID10_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID11_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID11_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID13_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID13_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID14_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID14_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID15(1)_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID15(1)_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID15_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID15_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID16_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID16_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID18_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID18_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID19_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID19_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID1_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID1_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID20_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID20_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID21_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.3s.
# ✅ ICA completed and image saved: ID21_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID22_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID22_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID23_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.3s.
# ✅ ICA completed and image saved: ID23_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID24_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID24_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID25_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID25_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID26_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID26_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID27_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID27_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID2_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID2_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID30_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID30_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID31_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 1.2s.
# ✅ ICA completed and image saved: ID31_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID33_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID33_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID35_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID35_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID37_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID37_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID38_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID38_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID39_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID39_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID3_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.3s.
# ✅ ICA completed and image saved: ID3_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID40_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID40_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID41_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID41_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID43_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID43_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID4_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID4_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID5_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID5_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID6_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID6_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID7_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID7_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID8_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID8_EO_ICA_Components_EO_V2.png
#
# ⚙️ Processing file: ID9_EO.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\838558914.py:41: RuntimeWarning: Using n_components=10 (resulting in n_components_=10) may lead to an unstable mixing matrix estimation because the ratio between the largest (24) and smallest (2.2e-05) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 9
#   ica.fit(raw_ica)
# ✅ ICA completed and image saved: ID9_EO_ICA_Components_EO_V2.png
#
# 🎯 All EO ICA component plots saved in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\pain_dataset_outputs\EO-ICA-Components_V2

# %% [markdown]
# ## **Artifact Removal**

# %%
import mne
import numpy as np
from pathlib import Path
from mne_icalabel import label_components   # pip install mne-icalabel

# config
in_dir = Path("Segments/EO")            # your input .fif files
out_dir = Path("Data-After-Artifact/EO")
out_dir.mkdir(parents=True, exist_ok=True)

# thresholds (tweak if you wish)
ICLABEL_ARTIFACT_THRESH = 0.7   # remove IC if artifact class prob >= this
BRAIN_PROB_MIN = 0.3            # require brain prob < this to consider removing when another artifact high

for ff in sorted(in_dir.glob("*.fif")):
    print("Processing", ff.name)
    raw = mne.io.read_raw_fif(ff, preload=True, verbose='ERROR')
    raw.pick_types(eeg=True)
    raw.set_eeg_reference('average', projection=True)

    # recommended filter for ICA fitting (research standard)
    raw_filt = raw.copy().filter(l_freq=1., h_freq=45.)

    # fit ICA
    ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
    ica.fit(raw_filt)

    # -------------------------
    # 1) Try automatic detectors using proxy channels
    # -------------------------
    bads = []

    # -- EOG: create a virtual EOG from frontal electrodes (if exist) --
    frontal_names = [ch for ch in raw.ch_names if ch.upper() in ('FP1', 'FP2', 'F7', 'F8')]
    if frontal_names:
        # simple proxy: use Fp1 (or Fp2 if missing), or bipolar Fp1-Fp2 if both present
        if 'Fp1' in [c.upper() for c in frontal_names] and 'Fp2' in [c.upper() for c in frontal_names]:
            # bipolar EOG: Fp1 - Fp2
            data_fp1 = raw.get_data(picks=['Fp1'])[0]
            data_fp2 = raw.get_data(picks=['Fp2'])[0]
            virt_eog = data_fp1 - data_fp2
            eog_ch = mne.io.RawArray(virt_eog[np.newaxis, :], 
                                     mne.create_info(['V_EOG'], sfreq=raw.info['sfreq'], ch_types=['eog']))
            # append virt channel to a copy for detection
            raw_for_detect = raw.copy().add_channels([eog_ch], force_update_info=True)
            try:
                eog_inds, eog_scores = ica.find_bads_eog(raw_for_detect, ch_name='V_EOG', threshold='auto')
                print("Proxy EOG detected components:", eog_inds)
                bads.extend(eog_inds)
            except Exception as e:
                print("find_bads_eog with virtual channel failed:", e)
        else:
            # fallback: use the first frontal channel as proxy
            chproxy = frontal_names[0]
            try:
                eog_inds, _ = ica.find_bads_eog(raw_filt, ch_name=chproxy)
                print("EOG proxy components via", chproxy, "->", eog_inds)
                bads.extend(eog_inds)
            except Exception as e:
                print("find_bads_eog proxy failed:", e)
    else:
        print("No frontal channels available for virtual EOG")

    # -- ECG: let find_bads_ecg attempt virtual ECG (MNE will try cross-channel averaging if no explicit ECG channel) --
    try:
        ecg_inds, ecg_scores = ica.find_bads_ecg(raw_filt, method='correlation', threshold='auto')
        print("ECG components:", ecg_inds)
        bads.extend(ecg_inds)
    except Exception as e:
        print("find_bads_ecg failed (no ECG channel) — will rely on ICLabel:", e)

    # -- muscle: use MNE's method (works without EMG channel) --
    try:
        muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
        print("Muscle components:", muscle_inds)
        bads.extend(muscle_inds)
    except Exception as e:
        print("find_bads_muscle failed or found none:", e)

    bads = sorted(set(bads))

    # -------------------------
    # 2) Use ICLabel (mne-icalabel) for a robust decision
    # -------------------------
    try:
        comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
        probs = comp_dict['y_pred_proba']   # shape (n_components, n_classes)
        # ICLabel order: ['brain','muscle artifact','eye blink','heart beat','line noise','channel noise','other']
        # decide which components to drop automatically:
        ncomps = probs.shape[0]
        iclabel_remove = []
        for ic in range(ncomps):
            brain_p = probs[ic, 0]
            muscle_p = probs[ic, 1]
            eye_p = probs[ic, 2]
            heart_p = probs[ic, 3]
            line_p = probs[ic, 4]
            channel_p = probs[ic, 5]
            # remove if any artifact class is strongly likely AND brain prob is not high
            if ((eye_p >= ICLABEL_ARTIFACT_THRESH or muscle_p >= ICLABEL_ARTIFACT_THRESH or heart_p >= ICLABEL_ARTIFACT_THRESH
                 or line_p >= ICLABEL_ARTIFACT_THRESH or channel_p >= ICLABEL_ARTIFACT_THRESH)
                and brain_p < BRAIN_PROB_MIN):
                iclabel_remove.append(ic)
        print("ICLabel flagged components:", iclabel_remove)
        bads = sorted(set(bads + iclabel_remove))
    except Exception as e:
        print("mne-icalabel failed or not installed:", e)
        print("Continuing with detectors found earlier.")

    # -------------------------
    # 3) Apply the final exclusion list and save cleaned file
    # -------------------------
    print("Final components to remove:", bads)
    ica.exclude = bads
    raw_clean = raw.copy()
    ica.apply(raw_clean)

    # save as EDF (recommended). If you insist on GDF we can add pyEDFlib step instead.
    out_file = out_dir / f"{ff.stem}_clean.edf"
    raw_clean.export(out_file, fmt='auto')
    print("Saved cleaned:", out_file.name)
# Out:
# Processing ID0_EO.fif
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.5s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(0)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [4, 5, 8, 10, 13, 14]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [np.int64(0), 4, 5, 8, 10, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 7 ICA components
#     Projecting back using 24 PCA components
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# Saved cleaned: ID0_EO_clean.edf
# Processing ID10_EO.fif
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(4)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [0, 1, 2, 7, 8, 10]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [0, 1, 2, np.int64(4), 7, 8, 10]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 7 ICA components
#     Projecting back using 24 PCA components
# Saved cleaned: ID10_EO_clean.edf
# Processing ID11_EO.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(0)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [6, 10, 11]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [np.int64(0), 6, 10, 11]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 4 ICA components
#     Projecting back using 24 PCA components
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# Saved cleaned: ID11_EO_clean.edf
# Processing ID13_EO.fif
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.5s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(0)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [7, 14]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [np.int64(0), 7, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 3 ICA components
#     Projecting back using 24 PCA components
# Saved cleaned: ID13_EO_clean.edf
# Processing ID14_EO.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 2.1s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(6)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [0, 4, 5, 8, 10, 12, 13]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [0, 4, 5, np.int64(6), 8, 10, 12, 13]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 8 ICA components
#     Projecting back using 24 PCA components
# Saved cleaned: ID14_EO_clean.edf
# Processing ID15(1)_EO.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.5s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> []
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [3, 7, 8, 9, 10, 11, 13, 14]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [3, 7, 8, 9, 10, 11, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 8 ICA components
#     Projecting back using 24 PCA components
# Saved cleaned: ID15(1)_EO_clean.edf
# Processing ID15_EO.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> []
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [3, 7, 8, 9, 10, 11, 13, 14]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [3, 7, 8, 9, 10, 11, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 8 ICA components
#     Projecting back using 24 PCA components
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# Saved cleaned: ID15_EO_clean.edf
# Processing ID16_EO.fif
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(0)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [11, 13, 14]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [np.int64(0), 11, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 4 ICA components
#     Projecting back using 24 PCA components
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# Saved cleaned: ID16_EO_clean.edf
# Processing ID18_EO.fif
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(0)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [10, 12]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [np.int64(0), 10, 12]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 3 ICA components
#     Projecting back using 24 PCA components
# Saved cleaned: ID18_EO_clean.edf
# Processing ID19_EO.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(0)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [5, 7, 8, 9, 10, 14]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [np.int64(0), 5, 7, 8, 9, 10, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 7 ICA components
#     Projecting back using 24 PCA components
# Saved cleaned:
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
# ...
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> [np.int64(1)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [0, 5, 12, 13]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [0, np.int64(1), 5, 12, 13]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 5 ICA components
#     Projecting back using 24 PCA components
# Saved cleaned: ID7_EO_clean.edf
# Processing ID8_EO.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# EOG proxy components via FP1 -> []
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [1, 2, 5, 6, 7, 8, 12, 13, 14]
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [1, 2, 5, 6, 7, 8, 12, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 9 ICA components
#     Projecting back using 24 PCA components
# Saved cleaned: ID8_EO_clean.edf
# Processing ID9_EO.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# Using EOG channel: FP1
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:26: RuntimeWarning: Using n_components=15 (resulting in n_components_=15) may lead to an unstable mixing matrix estimation because the ratio between the largest (24) and smallest (9.6e-06) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 9
#   ica.fit(raw_filt)
# EOG proxy components via FP1 -> [np.int64(1)]
# find_bads_ecg failed (no ECG channel) — will rely on ICLabel: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: []
# mne-icalabel failed or not installed: Montage is not set. Please set the montage to provide the electrode positions.
# Continuing with detectors found earlier.
# Final components to remove: [np.int64(1)]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 24 PCA components
# Saved cleaned: ID9_EO_clean.edf
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:74: RuntimeWarning: No sensor positions found. Scores for bad muscle components are only based on the 'slope' criterion.
#   muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:86: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba' and 'labels'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(out_file, fmt='auto')
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1873775325.py:120: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(out_file, fmt='auto')

# %%
"""
Full ICA cleaning pipeline with:
 - vertical EOG (FP1 - FP2)
 - horizontal EOG (F7 - F8)
 - ECG & muscle automatic detection
 - ICLabel (mne-icalabel) automatic classification
 - Save cleaned outputs in:
     Data-After-Artifact/EO/EDF/
     Data-After-Artifact/EO/FIF/
     Data-After-Artifact/EO/NPY/
 - Robust handling of channel name cases and number of ICA components
"""

import mne
import numpy as np
from pathlib import Path

# Optional (ICLabel). If not installed, the pipeline will continue without it.
try:
    from mne_icalabel import label_components
    HAVE_ICLABEL = True
except Exception:
    HAVE_ICLABEL = False
    print("mne-icalabel not installed — ICLabel step will be skipped. Install with: pip install mne-icalabel")

# ----------------------------
# Configuration
# ----------------------------
in_dir = Path("Segments/EO")                # input .fif files
out_base = Path("Data-After-Artifact-V2/EO")   # base output folder

edf_dir = out_base / "EDF"
fif_dir = out_base / "FIF"
npy_dir = out_base / "NPY"

edf_dir.mkdir(parents=True, exist_ok=True)
fif_dir.mkdir(parents=True, exist_ok=True)
npy_dir.mkdir(parents=True, exist_ok=True)

# thresholds (tweak as needed)
ICLABEL_ARTIFACT_THRESH = 0.7   # remove if artifact class prob >= this
BRAIN_PROB_MIN = 0.3            # only remove if brain prob < this

# ----------------------------
# Helper
# ----------------------------
def safe_n_components(raw_info, desired=15):
    """Return a safe n_components for ICA fitting based on channel count."""
    nchan = raw_info['nchan']
    # leave at least 1 component, and <= nchan - 1
    return max(1, min(desired, nchan - 1))

# ----------------------------
# Main loop
# ----------------------------
for ff in sorted(in_dir.glob("*.fif")):
    print("\n" + "="*60)
    print("Processing:", ff.name)
    print("="*60)

    # 1) Load
    raw = mne.io.read_raw_fif(ff, preload=True, verbose='ERROR')
    # Select EEG channels only
    raw.pick_types(eeg=True)
    # Attach a standard montage so later plotting or topomaps (if used) won't fail.
    raw.set_montage("standard_1020", on_missing="ignore")

    # Set average reference (use projection for stability)
    try:
        raw.set_eeg_reference('average', projection=True)
    except Exception as e:
        print("Warning: couldn't set average reference:", e)

    # 2) Prepare filtered copy for ICA fitting
    raw_filt = raw.copy().filter(l_freq=1., h_freq=45., verbose='ERROR')

    # 3) Fit ICA with safe number of components
    n_comps = safe_n_components(raw.info, desired=15)
    print(f"Fitting ICA with n_components={n_comps} (channels={raw.info['nchan']})")
    ica = mne.preprocessing.ICA(n_components=n_comps, random_state=97, max_iter='auto')
    ica.fit(raw_filt)

    # ---------- automatic detectors ----------
    bads = []

    # --- Vertical EOG: FP1 - FP2 (your dataset has FP1/FP2 uppercase) ---
    if ('FP1' in raw.ch_names) and ('FP2' in raw.ch_names):
        print("Using vertical EOG proxy: FP1 - FP2")
        data_fp1 = raw.get_data(picks=['FP1'])[0]
        data_fp2 = raw.get_data(picks=['FP2'])[0]
        virt_v_eog = data_fp1 - data_fp2  # bipolar vertical
        eog_v = mne.io.RawArray(virt_v_eog[np.newaxis, :],
                                mne.create_info(['V_EOG'], sfreq=raw.info['sfreq'], ch_types=['eog']))
        raw_for_detect = raw.copy().add_channels([eog_v], force_update_info=True)
        try:
            v_eog_inds, v_scores = ica.find_bads_eog(raw_for_detect, ch_name='V_EOG', threshold='auto')
            print("Vertical EOG components:", v_eog_inds)
            bads.extend(v_eog_inds)
        except Exception as e:
            print("Vertical EOG detection failed:", e)
    else:
        print("FP1/FP2 not both present; skipping vertical EOG detection.")

    # --- Horizontal EOG: F7 - F8 (left-right eye movements) ---
    if ('F7' in raw.ch_names) and ('F8' in raw.ch_names):
        print("Using horizontal EOG proxy: F7 - F8")
        data_f7 = raw.get_data(picks=['F7'])[0]
        data_f8 = raw.get_data(picks=['F8'])[0]
        virt_h_eog = data_f7 - data_f8  # bipolar horizontal
        eog_h = mne.io.RawArray(virt_h_eog[np.newaxis, :],
                                mne.create_info(['H_EOG'], sfreq=raw.info['sfreq'], ch_types=['eog']))
        raw_for_hdetect = raw.copy().add_channels([eog_h], force_update_info=True)
        try:
            h_eog_inds, h_scores = ica.find_bads_eog(raw_for_hdetect, ch_name='H_EOG', threshold='auto')
            print("Horizontal EOG components:", h_eog_inds)
            bads.extend(h_eog_inds)
        except Exception as e:
            print("Horizontal EOG detection failed:", e)
    else:
        print("F7/F8 not both present; skipping horizontal EOG detection.")

    # --- ECG detection (may try to synthesize ECG if none exists) ---
    try:
        ecg_inds, ecg_scores = ica.find_bads_ecg(raw_filt, method='correlation', threshold='auto')
        print("ECG components:", ecg_inds)
        bads.extend(ecg_inds)
    except Exception as e:
        print("ECG detection failed or not reliable:", e)

    # --- Muscle detection ---
    try:
        muscle_inds, muscle_scores = ica.find_bads_muscle(raw_filt)
        print("Muscle components:", muscle_inds)
        bads.extend(muscle_inds)
    except Exception as e:
        print("Muscle detection failed or none found:", e)

    # deduplicate
    bads = sorted(set(bads))

    # ---------- ICLabel classification ----------
    iclabel_removed = []
    if HAVE_ICLABEL:
        try:
            comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
            probs = comp_dict['y_pred_proba']
            # ICLabel ordering: ['brain','muscle artifact','eye blink','heart beat','line noise','channel noise','other']
            for ic_idx in range(probs.shape[0]):
                brain_p = probs[ic_idx, 0]
                muscle_p = probs[ic_idx, 1]
                eye_p = probs[ic_idx, 2]
                heart_p = probs[ic_idx, 3]
                line_p = probs[ic_idx, 4]
                channel_p = probs[ic_idx, 5]

                # remove if artifact prob high AND brain prob low
                if ((muscle_p >= ICLABEL_ARTIFACT_THRESH or
                     eye_p >= ICLABEL_ARTIFACT_THRESH or
                     heart_p >= ICLABEL_ARTIFACT_THRESH or
                     line_p >= ICLABEL_ARTIFACT_THRESH or
                     channel_p >= ICLABEL_ARTIFACT_THRESH)
                        and (brain_p < BRAIN_PROB_MIN)):
                    iclabel_removed.append(ic_idx)

            print("ICLabel flagged components:", iclabel_removed)
            bads = sorted(set(bads + iclabel_removed))
        except Exception as e:
            print("ICLabel failed at runtime:", e)
    else:
        print("Skipping ICLabel (not installed).")

    # ---------- Apply exclusions and create cleaned raw ----------
    print("Final components to exclude:", bads)
    ica.exclude = bads

    raw_clean = raw.copy()
    ica.apply(raw_clean)

    # ---------- Save cleaned data in 3 formats ----------
    # Save EDF (requires edfio installed)
    edf_file = edf_dir / f"{ff.stem}_clean.edf"
    try:
        raw_clean.export(edf_file, fmt='edf', overwrite=True)
        print("Saved EDF:", edf_file.name)
    except Exception as e:
        print("EDF export failed. Make sure 'edfio' is installed in this environment.")
        print("EDF error:", e)

    # Save FIF (native MNE)
    fif_file = fif_dir / f"{ff.stem}_clean.fif"
    try:
        raw_clean.save(fif_file, overwrite=True)
        print("Saved FIF:", fif_file.name)
    except Exception as e:
        print("FIF save failed:", e)

    # Save NPY/NPZ (data in µV) along with simple metadata (.npz)
    npy_file = npy_dir / f"{ff.stem}_clean.npz"
    try:
        data_uv = raw_clean.get_data() * 1e6  # convert Volts -> µV
        ch_names = raw_clean.ch_names
        sfreq = raw_clean.info['sfreq']
        removed_components = bads

        # Save as npz: data (channels x samples), ch_names, sfreq, removed_components
        np.savez_compressed(
            npy_file,
            data=data_uv.astype(np.float32),
            ch_names=np.array(ch_names, dtype=object),
            sfreq=np.float32(sfreq),
            removed_components=np.array(removed_components, dtype=np.int32)
        )
        print("Saved NPY/NPZ:", npy_file.name)
    except Exception as e:
        print("NPY save failed:", e)

    # Small per-file summary
    print(f"Done processing {ff.name} — removed components: {bads}")

print("\nALL DONE.")
# Out:
# ============================================================
# Processing: ID0_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 2.2s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: [np.int64(3)]
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [2, 4, 7, 8, 10, 13, 14]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [2, np.int64(3), 4, 7, 8, 10, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 8 ICA components
#     Projecting back using 24 PCA components
# Saved EDF: ID0_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID0_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID0_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID0_EO_clean.fif
# [done]
# Saved FIF: ID0_EO_clean.fif
# Saved NPY/NPZ: ID0_EO_clean.npz
# Done processing ID0_EO.fif — removed components: [2, np.int64(3), 4, 7, 8, 10, 13, 14]
#
# ============================================================
# Processing: ID10_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: [np.int64(0)]
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [0, 1, 2, 7, 8, 9, 10, 14]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [np.int64(0), 1, 2, 7, 8, 9, 10, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 8 ICA components
#     Projecting back using 24 PCA components
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# Saved EDF: ID10_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID10_EO_clean.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID10_EO_clean.fif
# [done]
# Saved FIF: ID10_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID10_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# Saved NPY/NPZ: ID10_EO_clean.npz
# Done processing ID10_EO.fif — removed components: [np.int64(0), 1, 2, 7, 8, 9, 10, 14]
#
# ============================================================
# Processing: ID11_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.8s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: []
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [4, 6, 8, 9, 10, 11, 14]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [4, 6, 8, 9, 10, 11, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 7 ICA components
#     Projecting back using 24 PCA components
# Saved EDF: ID11_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID11_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID11_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID11_EO_clean.fif
# [done]
# Saved FIF: ID11_EO_clean.fif
# Saved NPY/NPZ: ID11_EO_clean.npz
# Done processing ID11_EO.fif — removed components: [4, 6, 8, 9, 10, 11, 14]
#
# ============================================================
# Processing: ID13_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.4s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: []
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [7, 12, 14]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [7, 12, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 3 ICA components
#     Projecting back using 24 PCA components
# Saved EDF: ID13_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID13_EO_clean.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID13_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID13_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# [done]
# Saved FIF: ID13_EO_clean.fif
# Saved NPY/NPZ: ID13_EO_clean.npz
# Done processing ID13_EO.fif — removed components: [7, 12, 14]
#
# ============================================================
# Processing: ID14_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 2.0s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: []
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [0, 1, 2, 3, 4, 5, 8, 9, 10, 12, 13, 14]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [0, 1, 2, 3, 4, 5, 8, 9, 10, 12, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 12 ICA components
#     Projecting back using 24 PCA components
# Saved EDF: ID14_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID14_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID14_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID14_EO_clean.fif
# [done]
# Saved FIF: ID14_EO_clean.fif
# Saved NPY/NPZ: ID14_EO_clean.npz
# Done processing ID14_EO.fif — removed components: [0, 1, 2, 3, 4, 5, 8, 9, 10, 12, 13, 14]
#
# ============================================================
# Processing: ID15(1)_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: []
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [3, 6, 7, 8, 9, 10, 11, 12, 13, 14]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [3, 6, 7, 8, 9, 10, 11, 12, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 10 ICA components
#     Projecting back using 24 PCA components
# Saved EDF: ID15(1)_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID15(1)_EO_clean.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID15(1)_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID15(1)_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# [done]
# Saved FIF: ID15(1)_EO_clean.fif
# Saved NPY/NPZ: ID15(1)_EO_clean.npz
# Done processing ID15(1)_EO.fif — removed components: [3, 6, 7, 8, 9, 10, 11, 12, 13, 14]
#
# ============================================================
# Processing: ID15_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: []
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [3, 6, 7, 8, 9, 10, 11, 12, 13, 14]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [3, 6, 7, 8, 9, 10, 11, 12, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 10 ICA components
#     Projecting back using 24 PCA components
# Saved EDF: ID15_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID15_EO_clean.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID15_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID15_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# [done]
# Saved FIF: ID15_EO_clean.fif
# Saved NPY/NPZ: ID15_EO_clean.npz
# Done processing ID15_EO.fif — removed components: [3, 6, 7, 8, 9, 10, 11, 12, 13, 14]
#
# ============================================================
# Processing: ID16_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.6s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: [np.int64(0)]
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# ...
# [done]
# Saved FIF: ID7_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID7_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# Saved NPY/NPZ: ID7_EO_clean.npz
# Done processing ID7_EO.fif — removed components: [0, 5, 6, 8, 9, 11, 12, 13, 14]
#
# ============================================================
# Processing: ID8_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: []
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [1, 2, 3, 4, 5, 6, 7, 8, 10, 11, 12, 13, 14]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [1, 2, 3, 4, 5, 6, 7, 8, 10, 11, 12, 13, 14]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 13 ICA components
#     Projecting back using 24 PCA components
# Saved EDF: ID8_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID8_EO_clean.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID8_EO_clean.fif
# [done]
# Saved FIF: ID8_EO_clean.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID8_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# Saved NPY/NPZ: ID8_EO_clean.npz
# Done processing ID8_EO.fif — removed components: [1, 2, 3, 4, 5, 6, 7, 8, 10, 11, 12, 13, 14]
#
# ============================================================
# Processing: ID9_EO.fif
# ============================================================
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Fitting ICA with n_components=15 (channels=24)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# Using vertical EOG proxy: FP1 - FP2
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: V_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:81: RuntimeWarning: Using n_components=15 (resulting in n_components_=15) may lead to an unstable mixing matrix estimation because the ratio between the largest (24) and smallest (9.6e-06) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 9
#   ica.fit(raw_filt)
# Vertical EOG components: []
# Using horizontal EOG proxy: F7 - F8
# Creating RawArray with float64 data, n_channels=1, n_times=75001
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Using EOG channel: H_EOG
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# Horizontal EOG components: [np.int64(0)]
# ECG detection failed or not reliable: Generating an artificial ECG channel can only be done for MEG data.
# Effective window size : 8.192 (s)
# Muscle components: [13]
# ICLabel failed at runtime: Channel position for ['FP1', 'FP2'] is missing. Please check the montage set, the channel names, and ensure that every channel has a position.
# Final components to exclude: [np.int64(0), 13]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 24 PCA components
# Saved EDF: ID9_EO_clean.edf
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID9_EO_clean.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID9_EO_clean.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance does not seem to be referenced to a common average reference (CAR). ICLabel was designed to classify features extracted from an EEG dataset referenced to a CAR (see the 'set_eeg_reference()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided Raw instance is not filtered between 1 and 100 Hz. ICLabel was designed to classify features extracted from an EEG dataset bandpass filtered between 1 and 100 Hz (see the 'filter()' method for Raw and Epochs instances).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:145: RuntimeWarning: The provided ICA instance was fitted with a 'fastica' algorithm. ICLabel was designed with extended infomax ICA decompositions. To use the extended infomax algorithm, use the 'mne.preprocessing.ICA' instance with the arguments 'ICA(method='infomax', fit_params=dict(extended=True))' (scikit-learn) or 'ICA(method='picard', fit_params=dict(ortho=False, extended=True))' (python-picard).
#   comp_dict = label_components(raw_filt, ica, method='iclabel')  # returns dict with 'y_pred_proba'
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: Raw instance has unapplied projectors. Consider applying them before exporting with raw.apply_proj().
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:183: RuntimeWarning: EDF format requires equal-length data blocks, so 0.996 seconds of edge values were appended to all channels when writing the final block.
#   raw_clean.export(edf_file, fmt='edf', overwrite=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\350448302.py:192: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact-V2\EO\FIF\ID9_EO_clean.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_clean.save(fif_file, overwrite=True)
# Saved FIF: ID9_EO_clean.fif
# Saved NPY/NPZ: ID9_EO_clean.npz
# Done processing ID9_EO.fif — removed components: [np.int64(0), 13]
#
# ALL DONE.

# %% [markdown]
# ## **Compare Old and New signals**

# %%
import mne

orig_file = "Segments/EO/ID0_EO.fif"
clean_file = "Data-After-Artifact/EO/ID0_EO_clean.edf"

raw_orig = mne.io.read_raw_fif(orig_file, preload=True)
raw_clean = mne.io.read_raw_edf(clean_file, preload=True)

# Restrict to EEG channels
raw_orig.pick_types(eeg=True)
raw_clean.pick_types(eeg=True)

# Plot original
raw_orig.plot(title="Original EEG (Before ICA Cleaning)")

# Plot cleaned
raw_clean.plot(title="Cleaned EEG (After ICA Cleaning)")
# Out:
# Opening raw data file Segments/EO/ID0_EO.fif...
# Isotrak not found
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Reading 0 ... 75000  =      0.000 ...   300.000 secs...
# Extracting EDF parameters from c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact\EO\ID0_EO_clean.edf...
# EDF file detected
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\1561293223.py:6: RuntimeWarning: This filename (Segments/EO/ID0_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_orig = mne.io.read_raw_fif(orig_file, preload=True)
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75249  =      0.000 ...   300.996 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
import mne

raw_orig = mne.io.read_raw_fif("Segments/EO/ID0_EO.fif", preload=True)
raw_orig.pick_types(eeg=True)
raw_orig.set_eeg_reference('average', projection=True)

raw_filt = raw_orig.copy().filter(1, 45)

ica = mne.preprocessing.ICA(n_components=15, random_state=97)
ica.fit(raw_filt)

ica.plot_components(title="ICA Components (Original)")
ica.plot_sources(raw_orig, title="Sources Before Cleaning")
# Out:
# Opening raw data file Segments/EO/ID0_EO.fif...
# Isotrak not found
#     Range : 0 ... 75000 =      0.000 ...   300.000 secs
# Ready.
# Reading 0 ... 75000  =      0.000 ...   300.000 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# C:\Users\User\AppData\Local\Temp\ipykernel_14376\2235179246.py:3: RuntimeWarning: This filename (Segments/EO/ID0_EO.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw_orig = mne.io.read_raw_fif("Segments/EO/ID0_EO.fif", preload=True)
# Selecting by number: 15 components
# Fitting ICA took 1.4s.
# WARNING:root:Did not find any electrode locations (in the info object), will attempt to use digitization points instead. However, if digitization points do not correspond to the EEG electrodes, this will lead to bad results. Please verify that the sensor locations in the plot are accurate.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 12
#       9 ica = mne.preprocessing.ICA(n_components=15, random_state=97)
#      10 ica.fit(raw_filt)
# ---> 12 ica.plot_components(title="ICA Components (Original)")
#      13 ica.plot_sources(raw_orig, title="Sources Before Cleaning")
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\preprocessing\ica.py:2501, in ICA.plot_components(self, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#    2468 @copy_function_doc_to_method_doc(plot_ica_components)
#    2469 def plot_components(
#    2470     self,
#    (...)   2499     verbose=None,
#    2500 ):
# -> 2501     return plot_ica_components(
#    2502         self,
#    2503         picks=picks,
#    2504         ch_type=ch_type,
#    2505         inst=inst,
#    2506         plot_std=plot_std,
#    2507         reject=reject,
#    2508         sensors=sensors,
#    2509         show_names=show_names,
#    2510         contours=contours,
#    2511         outlines=outlines,
#    2512         sphere=sphere,
#    2513         image_interp=image_interp,
#    2514         extrapolate=extrapolate,
#    2515         border=border,
#    2516         res=res,
#    2517         size=size,
#    2518         cmap=cmap,
#    2519         vlim=vlim,
#    2520         cnorm=cnorm,
#    2521         colorbar=colorbar,
#    2522         cbar_fmt=cbar_fmt,
#    2523         axes=axes,
#    2524         title=title,
#    2525         nrows=nrows,
#    2526         ncols=ncols,
#    2527         show=show,
#    2528         image_args=image_args,
#    2529         psd_args=psd_args,
#    2530         verbose=verbose,
#    2531     )
#
# File <decorator-gen-143>:12, in plot_ica_components(ica, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\viz\topomap.py:1709, in plot_ica_components(ica, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#    1698 except TypeError:  # None or Axes
#    1699     _axes = axes
#    1701 (
#    1702     data_picks,
#    1703     pos,
#    1704     merge_channels,
#    1705     names,
#    1706     ch_type,
#    1707     sphere,
#    1708     clip_origin,
# -> 1709 ) = _prepare_topomap_plot(ica, ch_type, sphere=sphere)
#    1710 cmap = _setup_cmap(cmap, n_axes=len(picks))
#    1711 disp_names = _prepare_sensor_names(names, show_names)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\viz\topomap.py:136, in _prepare_topomap_plot(inst, ch_type, sphere)
#     133     modality = "other"
#     135 # special case for merging grad channels
# --> 136 layout = find_layout(info)
#     137 if (
#     138     ch_type == "grad"
#     139     and layout is not None
#    (...)    143     )
#     144 ):
#     145     picks, _ = _pair_grad_sensors(info, layout)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\channels\layout.py:629, in find_layout(info, ch_type, exclude)
#     624     if not isinstance(info, dict | Info):
#     625         raise RuntimeError(
#     626             "Cannot make EEG layout, no measurement info "
#     627             "was passed to `find_layout`"
#     628         )
# --> 629     return make_eeg_layout(info, exclude=exclude)
#     630 elif has_csd_coils and ch_type in [None, "csd"]:
#     631     return make_eeg_layout(info, exclude=exclude, csd=True)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\channels\layout.py:447, in make_eeg_layout(info, radius, width, height, exclude, csd)
#     445     pick_kwargs.update(csd=True, eeg=False)
#     446 picks = pick_types(info, **pick_kwargs)
# --> 447 loc2d = _find_topomap_coords(info, picks)
#     448 names = [info["chs"][i]["ch_name"] for i in picks]
#     450 # Scale [x, y] to be in the range [-0.5, 0.5]
#     451 # Don't mess with the origin or aspect ratio
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\channels\layout.py:860, in _find_topomap_coords(info, picks, layout, ignore_overlap, to_sphere, sphere)
#     858     pos = np.asarray(pos)
#     859 else:
# --> 860     pos = _auto_topomap_coords(
#     861         info,
#     862         picks,
#     863         ignore_overlap=ignore_overlap,
#     864         to_sphere=to_sphere,
#     865         sphere=sphere,
#     866     )
#     868 return pos
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\channels\layout.py:933, in _auto_topomap_coords(info, picks, ignore_overlap, to_sphere, sphere)
#     931 # Get EEG digitization points
#     932 if info["dig"] is None or len(info["dig"]) == 0:
# --> 933     raise RuntimeError("No digitization points found.")
#     935 locs3d = np.array(
#     936     [
#     937         point["r"]
#    (...)    940     ]
#     941 )
#     943 if len(locs3d) == 0:
#
# RuntimeError: No digitization points found.

# %%
raw_clean = mne.io.read_raw_edf("Data-After-Artifact/EO/ID0_EO_clean.edf", preload=True)
raw_clean.pick_types(eeg=True)
raw_clean.set_eeg_reference('average', projection=True)
raw_clean_filt = raw_clean.copy().filter(1, 45)

ica_clean = mne.preprocessing.ICA(n_components=15, random_state=97)
ica_clean.fit(raw_clean_filt)

ica_clean.plot_components(title="ICA Components (Cleaned File)")
ica_clean.plot_sources(raw_clean, title="Sources After Cleaning")
# Out:
# Extracting EDF parameters from c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Data-After-Artifact\EO\ID0_EO_clean.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 75249  =      0.000 ...   300.996 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Omitting 249 of 75250 (0.33%) samples, retaining 75001 (99.67%) samples.
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# WARNING:root:Did not find any electrode locations (in the info object), will attempt to use digitization points instead. However, if digitization points do not correspond to the EEG electrodes, this will lead to bad results. Please verify that the sensor locations in the plot are accurate.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 9
#       6 ica_clean = mne.preprocessing.ICA(n_components=15, random_state=97)
#       7 ica_clean.fit(raw_clean_filt)
# ----> 9 ica_clean.plot_components(title="ICA Components (Cleaned File)")
#      10 ica_clean.plot_sources(raw_clean, title="Sources After Cleaning")
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\preprocessing\ica.py:2501, in ICA.plot_components(self, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#    2468 @copy_function_doc_to_method_doc(plot_ica_components)
#    2469 def plot_components(
#    2470     self,
#    (...)   2499     verbose=None,
#    2500 ):
# -> 2501     return plot_ica_components(
#    2502         self,
#    2503         picks=picks,
#    2504         ch_type=ch_type,
#    2505         inst=inst,
#    2506         plot_std=plot_std,
#    2507         reject=reject,
#    2508         sensors=sensors,
#    2509         show_names=show_names,
#    2510         contours=contours,
#    2511         outlines=outlines,
#    2512         sphere=sphere,
#    2513         image_interp=image_interp,
#    2514         extrapolate=extrapolate,
#    2515         border=border,
#    2516         res=res,
#    2517         size=size,
#    2518         cmap=cmap,
#    2519         vlim=vlim,
#    2520         cnorm=cnorm,
#    2521         colorbar=colorbar,
#    2522         cbar_fmt=cbar_fmt,
#    2523         axes=axes,
#    2524         title=title,
#    2525         nrows=nrows,
#    2526         ncols=ncols,
#    2527         show=show,
#    2528         image_args=image_args,
#    2529         psd_args=psd_args,
#    2530         verbose=verbose,
#    2531     )
#
# File <decorator-gen-143>:12, in plot_ica_components(ica, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\viz\topomap.py:1709, in plot_ica_components(ica, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#    1698 except TypeError:  # None or Axes
#    1699     _axes = axes
#    1701 (
#    1702     data_picks,
#    1703     pos,
#    1704     merge_channels,
#    1705     names,
#    1706     ch_type,
#    1707     sphere,
#    1708     clip_origin,
# -> 1709 ) = _prepare_topomap_plot(ica, ch_type, sphere=sphere)
#    1710 cmap = _setup_cmap(cmap, n_axes=len(picks))
#    1711 disp_names = _prepare_sensor_names(names, show_names)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\viz\topomap.py:136, in _prepare_topomap_plot(inst, ch_type, sphere)
#     133     modality = "other"
#     135 # special case for merging grad channels
# --> 136 layout = find_layout(info)
#     137 if (
#     138     ch_type == "grad"
#     139     and layout is not None
#    (...)    143     )
#     144 ):
#     145     picks, _ = _pair_grad_sensors(info, layout)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\channels\layout.py:629, in find_layout(info, ch_type, exclude)
#     624     if not isinstance(info, dict | Info):
#     625         raise RuntimeError(
#     626             "Cannot make EEG layout, no measurement info "
#     627             "was passed to `find_layout`"
#     628         )
# --> 629     return make_eeg_layout(info, exclude=exclude)
#     630 elif has_csd_coils and ch_type in [None, "csd"]:
#     631     return make_eeg_layout(info, exclude=exclude, csd=True)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\channels\layout.py:447, in make_eeg_layout(info, radius, width, height, exclude, csd)
#     445     pick_kwargs.update(csd=True, eeg=False)
#     446 picks = pick_types(info, **pick_kwargs)
# --> 447 loc2d = _find_topomap_coords(info, picks)
#     448 names = [info["chs"][i]["ch_name"] for i in picks]
#     450 # Scale [x, y] to be in the range [-0.5, 0.5]
#     451 # Don't mess with the origin or aspect ratio
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\channels\layout.py:860, in _find_topomap_coords(info, picks, layout, ignore_overlap, to_sphere, sphere)
#     858     pos = np.asarray(pos)
#     859 else:
# --> 860     pos = _auto_topomap_coords(
#     861         info,
#     862         picks,
#     863         ignore_overlap=ignore_overlap,
#     864         to_sphere=to_sphere,
#     865         sphere=sphere,
#     866     )
#     868 return pos
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\channels\layout.py:933, in _auto_topomap_coords(info, picks, ignore_overlap, to_sphere, sphere)
#     931 # Get EEG digitization points
#     932 if info["dig"] is None or len(info["dig"]) == 0:
# --> 933     raise RuntimeError("No digitization points found.")
#     935 locs3d = np.array(
#     936     [
#     937         point["r"]
#    (...)    940     ]
#     941 )
#     943 if len(locs3d) == 0:
#
# RuntimeError: No digitization points found.

# %%
import matplotlib.pyplot as plt

ch = "Fp1"  # choose channel

data_orig, times = raw_orig.get_data(picks=[ch], return_times=True)
data_clean, _ = raw_clean.get_data(picks=[ch], return_times=True)

plt.figure(figsize=(15,5))
plt.plot(times[:5000], data_orig[0, :5000], label="Original", alpha=0.7)
plt.plot(times[:5000], data_clean[0, :5000], label="Cleaned", alpha=0.7)
plt.legend()
plt.title(f"Channel: {ch} (First 20 seconds)")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (V)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 5
#       1 import matplotlib.pyplot as plt
#       3 ch = "Fp1"  # choose channel
# ----> 5 data_orig, times = raw_orig.get_data(picks=[ch], return_times=True)
#       6 data_clean, _ = raw_clean.get_data(picks=[ch], return_times=True)
#       8 plt.figure(figsize=(15,5))
#
# File <decorator-gen-192>:12, in get_data(self, picks, start, stop, reject_by_annotation, return_times, units, tmin, tmax, verbose)
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\io\base.py:954, in BaseRaw.get_data(self, picks, start, stop, reject_by_annotation, return_times, units, tmin, tmax, verbose)
#     949 _validate_type(start, types=("int-like"), item_name="start", type_name="int")
#     950 _validate_type(
#     951     stop, types=("int-like", None), item_name="stop", type_name="int, None"
#     952 )
# --> 954 picks = _picks_to_idx(self.info, picks, "all", exclude=())
#     956 # Get channel factors for conversion into specified unit
#     957 # (vector of ones if no conversion needed)
#     958 if units is not None:
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\_fiff\pick.py:1257, in _picks_to_idx(info, picks, none, exclude, allow_empty, with_ref_meg, return_kind, picks_on)
#    1255     raise ValueError(f"picks must be 1D, got {picks.ndim}D")
#    1256 if picks.dtype.char in ("S", "U"):
# -> 1257     picks = _picks_str_to_idx(
#    1258         info,
#    1259         picks,
#    1260         exclude,
#    1261         with_ref_meg,
#    1262         return_kind,
#    1263         extra_repr,
#    1264         allow_empty,
#    1265         orig_picks,
#    1266     )
#    1267     if return_kind:
#    1268         picked_ch_type_or_generic = picks[1]
#
# File c:\Users\User\Desktop\TCS-PROJECTS\envfirst\Lib\site-packages\mne\_fiff\pick.py:1394, in _picks_str_to_idx(info, picks, exclude, with_ref_meg, return_kind, extra_repr, allow_empty, orig_picks)
#    1392 if sum(any_found) == 0:
#    1393     if not allow_empty:
# -> 1394         raise ValueError(
#    1395             f"picks ({repr(orig_picks) + extra_repr}) could not be interpreted as "
#    1396             f'channel names (no channel "{bad_names}"), channel types (no type'
#    1397             f' "{bad_type}" present), or a generic type (just "all" or "data")'
#    1398         )
#    1399     picks = np.array([], int)
#    1400 elif sum(any_found) > 1:
#
# ValueError: picks (['Fp1']) could not be interpreted as channel names (no channel "[np.str_('Fp1')]"), channel types (no type "Fp1" present), or a generic type (just "all" or "data")

# %%
diff = raw_orig.get_data() - raw_clean.get_data()
plt.plot(diff[0][:5000])  # first channel, first 20 seconds
plt.title("Difference (Original - Cleaned)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 diff = raw_orig.get_data() - raw_clean.get_data()
#       2 plt.plot(diff[0][:5000])  # first channel, first 20 seconds
#       3 plt.title("Difference (Original - Cleaned)")
#
# ValueError: operands could not be broadcast together with shapes (24,75001) (24,75250)

# %% [markdown]
# ### **For All EC Components**

# %%
# ( this is for single file No need to save it in folder ) .

import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define paths ---
example_file = Path("Segments\EC\ID0_EC.fif")  # actual file path


# --- Load .fif file ---
raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

# --- Check basic info ---
print(raw_example.info)

# --- Rename FP1, FP2 if needed ---
rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}

if rename_dict:
    print("Renaming channels:", rename_dict)
    raw_example.rename_channels(rename_dict)

# --- Set standard montage ---
try:
    raw_example.set_montage('standard_1020', on_missing='ignore')
    print(" Montage set successfully with 'standard_1020'")
except Exception as e:
    print(" Montage assignment issue:", e)


# --- Filter and reference before ICA ---
raw_example.pick_types(eeg=True)
raw_example.set_eeg_reference('average', projection=True)
raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

# --- Run ICA ---
ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
ica.fit(raw_ica)

# --- Plot ICA components ---
ica.plot_components()  # Shows interactively



print(f"✅ ICA completed for {example_file.name}")
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: FP1, FP2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T7, T8, P7, ...
#  chs: 24 EEG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 24
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: X>
# >
# Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
#  Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# <MNEFigure size 975x731.5 with 15 Axes>
# ✅ ICA completed for ID0_EC.fif

# %%
# method 2 ( this is for single file No need to save it in folder ) .

import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define paths ---
example_file = Path("Segments\EC\ID0_EC.fif")  # actual file path


# --- Load .fif file ---
raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

# --- Check basic info ---
print(raw_example.info)

# --- Rename FP1, FP2 if needed ---
rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}

if rename_dict:
    print("Renaming channels:", rename_dict)
    raw_example.rename_channels(rename_dict)

# --- Set standard montage ---
try:
    raw_example.set_montage('standard_1020', on_missing='ignore')
    print(" Montage set successfully with 'standard_1020'")
except Exception as e:
    print(" Montage assignment issue:", e)


# --- Filter and reference before ICA ---
raw_example.pick_types(eeg=True)
raw_example.set_eeg_reference('average', projection=True)
raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

# --- Run ICA ---
ica = mne.preprocessing.ICA(n_components=24, random_state=97, max_iter='auto')
ica.fit(raw_ica)

# --- Plot ICA components ---
ica.plot_components()  # Shows interactively



print(f"✅ ICA completed for {example_file.name}")
# Out:
# <Info | 10 non-empty values
#  bads: []
#  ch_names: FP1, FP2, F3, F4, C3, C4, P3, P4, O1, O2, F7, F8, T7, T8, P7, ...
#  chs: 24 EEG
#  custom_ref_applied: False
#  file_id: 4 items (dict)
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: unspecified
#  meas_id: 4 items (dict)
#  nchan: 24
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: <subject_info | his_id: X>
# >
# Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
#  Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 24 components
# Fitting ICA took 1.6s.
# <MNEFigure size 975x967 with 20 Axes>
# <MNEFigure size 780x260.5 with 4 Axes>
# ✅ ICA completed for ID0_EC.fif

# %%
import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define input/output paths ---
ec_dir = Path("Segments/EC")               # Folder with EO .fif files
OUTPUT_DIR = Path("pain_dataset_outputs")
output_subdir = OUTPUT_DIR / "EC-ICA-Components"  # New subfolder for ICA images 

output_subdir.mkdir(parents=True, exist_ok=True)

print(f"\n📁 Searching for EC files in: {ec_dir.resolve()}")

# --- Iterate through all EO .fif files ---
for example_file in sorted(ec_dir.glob("*.fif")):
    print(f"\n⚙️ Processing file: {example_file.name}")

    # --- Load .fif file ---
    raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

    # --- Rename FP1, FP2 if needed ---
    rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}
    if rename_dict:
        print("🔤 Renaming channels:", rename_dict)
        raw_example.rename_channels(rename_dict)

    # --- Set standard montage ---
    try:
        raw_example.set_montage('standard_1020', on_missing='ignore')
        print("🧠 Montage set successfully with 'standard_1020'")
    except Exception as e:
        print(f"⚠️ Montage assignment issue: {e}")

    # --- Filter and reference before ICA ---
    raw_example.pick_types(eeg=True)
    raw_example.set_eeg_reference('average', projection=True)
    raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

    # --- Run ICA ---
    ica = mne.preprocessing.ICA(n_components=15, random_state=97, max_iter='auto')
    ica.fit(raw_ica)

    # --- Plot ICA components (optional interactive view) ---
    # ica.plot_components()  # this show pictures in terminal

    # --- Save ICA component grid image ---
    fig = ica.plot_components(show=False)
    save_path = output_subdir / f"{example_file.stem}_ICA_Components_EC.png"
    fig.savefig(save_path, dpi=150)
    plt.close(fig)

    print(f"✅ ICA completed and image saved: {save_path.name}")

print(f"\n🎯 All EC ICA component plots saved in: {output_subdir.resolve()}")
# Out:
# 📁 Searching for EC files in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC
#
# ⚙️ Processing file: ID0_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID0_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID10_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID10_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID11_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID11_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID13_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID13_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID14_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.5s.
# ✅ ICA completed and image saved: ID14_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID15(1)_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID15(1)_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID15_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID15_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID16_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID16_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID18_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID18_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID19_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID19_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID1_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID1_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID20_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.9s.
# ✅ ICA completed and image saved: ID20_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID21_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID21_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID22_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.3s.
# ✅ ICA completed and image saved: ID22_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID23_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID23_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID24_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# ✅ ICA completed and image saved: ID24_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID25_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.3s.
# ✅ ICA completed and image saved: ID25_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID26_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.2s.
# ✅ ICA completed and image saved: ID26_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID27_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID27_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID2_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.9s.
# ✅ ICA completed and image saved: ID2_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID30_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID30_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID31_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID31_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID33_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID33_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID35_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID35_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID37_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.1s.
# ✅ ICA completed and image saved: ID37_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID38_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID38_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID39_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 2.1s.
# ✅ ICA completed and image saved: ID39_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID3_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID3_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID40_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID40_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID41_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.6s.
# ✅ ICA completed and image saved: ID41_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID43_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID43_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID4_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID4_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID5_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID5_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID6_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID6_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID7_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID7_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID8_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID8_EC_ICA_Components_EC.png
#
# ⚙️ Processing file: ID9_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID9_EC_ICA_Components_EC.png
#
# 🎯 All EC ICA component plots saved in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\pain_dataset_outputs\EC-ICA-Components

# %%
# EC with 10 ICA components

import mne
import matplotlib.pyplot as plt
from pathlib import Path

# --- Define input/output paths ---
ec_dir = Path("Segments/EC")               # Folder with EO .fif files
OUTPUT_DIR = Path("pain_dataset_outputs")
output_subdir = OUTPUT_DIR / "EC-ICA-Components_v2"  # New subfolder for ICA images 

output_subdir.mkdir(parents=True, exist_ok=True)

print(f"\n📁 Searching for EC files in: {ec_dir.resolve()}")

# --- Iterate through all EO .fif files ---
for example_file in sorted(ec_dir.glob("*.fif")):
    print(f"\n⚙️ Processing file: {example_file.name}")

    # --- Load .fif file ---
    raw_example = mne.io.read_raw_fif(example_file, preload=True, verbose='ERROR')

    # --- Rename FP1, FP2 if needed ---
    rename_dict = {ch: ch.capitalize() for ch in raw_example.ch_names if ch.upper() in ['FP1', 'FP2']}
    if rename_dict:
        print("🔤 Renaming channels:", rename_dict)
        raw_example.rename_channels(rename_dict)

    # --- Set standard montage ---
    try:
        raw_example.set_montage('standard_1020', on_missing='ignore')
        print("🧠 Montage set successfully with 'standard_1020'")
    except Exception as e:
        print(f"⚠️ Montage assignment issue: {e}")

    # --- Filter and reference before ICA ---
    raw_example.pick_types(eeg=True)
    raw_example.set_eeg_reference('average', projection=True)
    raw_ica = raw_example.copy().filter(l_freq=1., h_freq=None)

    # --- Run ICA ---
    ica = mne.preprocessing.ICA(n_components=10, random_state=97, max_iter='auto')
    ica.fit(raw_ica)

    # --- Plot ICA components (optional interactive view) ---
    # ica.plot_components()  # this show pictures in terminal

    # --- Save ICA component grid image ---
    fig = ica.plot_components(show=False)
    save_path = output_subdir / f"{example_file.stem}_ICA_Components_EC_v2.png"
    fig.savefig(save_path, dpi=150)
    plt.close(fig)

    print(f"✅ ICA completed and image saved: {save_path.name}")

print(f"\n🎯 All EC ICA component plots saved in: {output_subdir.resolve()}")
# Out:
# 📁 Searching for EC files in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segments\EC
#
# ⚙️ Processing file: ID0_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID0_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID10_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID10_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID11_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.3s.
# ✅ ICA completed and image saved: ID11_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID13_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID13_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID14_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID14_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID15(1)_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID15(1)_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID15_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID15_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID16_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID16_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID18_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID18_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID19_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID19_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID1_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.3s.
# ✅ ICA completed and image saved: ID1_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID20_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID20_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID21_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID21_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID22_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID22_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID23_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID23_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID24_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID24_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID25_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID25_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID26_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID26_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID27_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID27_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID2_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID2_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID30_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID30_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID31_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.3s.
# ✅ ICA completed and image saved: ID31_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID33_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID33_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID35_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID35_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID37_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.9s.
# ✅ ICA completed and image saved: ID37_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID38_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID38_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID39_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.7s.
# ✅ ICA completed and image saved: ID39_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID3_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID3_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID40_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID40_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID41_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 1.0s.
# ✅ ICA completed and image saved: ID41_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID43_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID43_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID4_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.5s.
# ✅ ICA completed and image saved: ID4_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID5_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.8s.
# ✅ ICA completed and image saved: ID5_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID6_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID6_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID7_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.4s.
# ✅ ICA completed and image saved: ID7_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID8_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID8_EC_ICA_Components_EC_v2.png
#
# ⚙️ Processing file: ID9_EC.fif
# 🔤 Renaming channels: {'FP1': 'Fp1', 'FP2': 'Fp2'}
# 🧠 Montage set successfully with 'standard_1020'
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Fitting ICA to data using 24 channels (please be patient, this may take a while)
# Selecting by number: 10 components
# Fitting ICA took 0.6s.
# ✅ ICA completed and image saved: ID9_EC_ICA_Components_EC_v2.png
#
# 🎯 All EC ICA component plots saved in: C:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\pain_dataset_outputs\EC-ICA-Components_v2

# %% [markdown]
# ### **Save EO and EC file Combinely in Segment Joined Folder and remove last extra 1 value**

# %%
import mne
from pathlib import Path
import numpy as np

# Directories
base = Path('Pain-Dataset')
save_dir = Path('Segment-Joined')
save_dir.mkdir(exist_ok=True)

for f in sorted(base.glob('*.gdf')):
    print(f"\n📁 Processing {f.name}")
    
    # Load raw data
    raw = mne.io.read_raw_gdf(str(f), preload=True, verbose='ERROR')
    ann = raw.annotations
    sfreq = raw.info['sfreq']
    total_dur = raw.times[-1]

    # --- Handle ID0 and ID26 separately ---
    if 'ID0' in f.name or 'ID26' in f.name:
        eo_start, eo_end = 0.0, 300.0
        ec_start = eo_end
        ec_end = np.floor(total_dur / 5) * 5  # round down to multiple of 5
        print(f"⚙️ Using fixed timing for {f.name}")
    else:
        # --- Normal case: derive timings from annotations ---
        codes = {desc: onset for onset, desc in zip(ann.onset, ann.description)}
        start1 = codes.get('33024', 0.0)       # EO start
        start2 = codes.get('33025', start1 + 300.0)  # EC start
        end = codes.get('33029', start2 + 300.0)     # End

        # EO desired = [5s, 305s], EC = [305s, 605s]
        eo_start = max(start1, 5.0)
        eo_end = eo_start + 300.0
        ec_start = eo_end
        ec_end = ec_start + 300.0

        # Clamp within total duration
        eo_end = min(eo_end, total_dur)
        ec_end = min(ec_end, total_dur)

        # Round to nearest multiple of 5
        def round_down_5(x):
            return np.floor(x / 5) * 5

        eo_start = round_down_5(eo_start)
        eo_end = round_down_5(eo_end)
        ec_start = round_down_5(ec_start)
        ec_end = round_down_5(ec_end)

        # Skip if segment too short
        if ec_end - ec_start < 5 or eo_end - eo_start < 5:
            print(f"⚠️ Skipped (too short): {f.name}")
            continue

    # --- Crop both segments ---
    eo = raw.copy().crop(tmin=eo_start, tmax=eo_end)
    ec = raw.copy().crop(tmin=ec_start, tmax=ec_end)

     # --- Debugging: Check shapes of data before removing rows ---
    print(f"Before removing last row:")
    print(f"EO data shape: {eo.get_data().shape} (channels, samples)")
    print(f"EC data shape: {ec.get_data().shape} (channels, samples)")

    # --- Remove last row if necessary ---
    if 'ID0' in f.name or 'ID26' in f.name:
        # For ID0 and ID26, remove last row from both EO and EC
        eo_data = eo.get_data()[:, :-1]  # Remove last row
        ec_data = ec.get_data()[:, :-1]  # Remove last row
    else: 
        # for Normal cases
        eo_data = eo.get_data()[:, :-1]  # Remove last row
        ec_data = ec.get_data()[:, :-1]  # Remove last row


    # --- Debugging: Check shapes after removing rows ---
    print(f"After removing last row:")
    print(f"EO data shape: {eo_data.shape} (channels, samples)")
    print(f"EC data shape: {ec_data.shape} (channels, samples)")

    # --- Check the number of channels before merging ---
    print(f"Number of channels in EO: {eo_data.shape[0]}")
    print(f"Number of channels in EC: {ec_data.shape[0]}")    

    # --- Merge EO and EC data ---
    combined_data = np.concatenate([eo_data, ec_data], axis=1)

    # --- Debugging: Check the shape of combined data ---
    print(f"Combined data shape: {combined_data.shape} (channels, samples)")

    # --- Save the merged data ---
    combined_raw = mne.io.RawArray(combined_data, info=eo.info)
    
    # Save merged .fif file
    combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)

    # Save merged .npy file
    np.save(save_dir / f"{f.stem}_combine.npy", combined_data)

    print(f"✅ Merged EO & EC: {eo_start:.1f}-{eo_end:.1f}s | {ec_start:.1f}-{ec_end:.1f}s | Total duration: {total_dur:.1f}s")

print("\n Segmentation and merging complete: all joint files saved successfully.")
# Out:
# 📁 Processing ID0.gdf
# ⚙️ Using fixed timing for ID0.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 73751) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 73750) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 148750) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=148750
#     Range : 0 ... 148749 =      0.000 ...   594.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID0_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID0_combine.fif
# [done]
# ✅ Merged EO & EC: 0.0-300.0s | 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID1.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID0_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID1_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID1_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID10.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID1_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID10_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID10_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID11.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID10_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID11_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID11_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID13.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID11_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID13_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID13_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID14.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID13_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID14_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID14_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15(1).gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID14_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15(1)_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15(1)_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID15.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15(1)_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID16.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID15_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID16_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID16_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID18.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID16_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID18_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID18_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID19.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID18_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID19_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID19_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID2.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID19_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID2_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID2_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID20.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID2_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID20_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID20_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID21.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID20_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID21_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID21_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID22.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID21_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID22_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID22_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID23.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID22_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID23_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID23_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID24.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID23_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID24_combine.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID24_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID24_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID25.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID25_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID25_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID26.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID25_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ⚙️ Using fixed timing for ID26.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 73751) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 73750) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 148750) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=148750
#     Range : 0 ... 148749 =      0.000 ...   594.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID26_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID26_combine.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID26_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# [done]
# ✅ Merged EO & EC: 0.0-300.0s | 300.0-595.0s | Total duration: 599.8s
#
# 📁 Processing ID27.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID27_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID27_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
# 📁 Processing ID3.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID27_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID3_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID3_combine.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID3_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID30.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID30_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID30_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID31.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID30_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID31_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID31_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID33.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID31_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID33_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID33_combine.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID33_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID35.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID35_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID35_combine.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID35_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID37.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID37_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID37_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID38.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID37_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID38_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID38_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID39.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID38_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID39_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID39_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID4.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID39_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID4_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID4_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID40.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID4_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID40_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID40_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID41.gdf
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID40_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID41_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID41_combine.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID41_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID43.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID43_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID43_combine.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID43_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID5.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID5_combine.fif
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID5_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID5_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID6.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID6_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID6_combine.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID6_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID7.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID7_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID7_combine.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID7_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID8.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID8_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID8_combine.fif
# [done]
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID8_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.8s
#
# 📁 Processing ID9.gdf
# Before removing last row:
# EO data shape: (24, 75001) (channels, samples)
# EC data shape: (24, 75001) (channels, samples)
# After removing last row:
# EO data shape: (24, 75000) (channels, samples)
# EC data shape: (24, 75000) (channels, samples)
# Number of channels in EO: 24
# Number of channels in EC: 24
# Combined data shape: (24, 150000) (channels, samples)
# Creating RawArray with float64 data, n_channels=24, n_times=150000
#     Range : 0 ... 149999 =      0.000 ...   599.996 secs
# Ready.
# Writing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID9_combine.fif
# Closing c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID9_combine.fif
# [done]
# ✅ Merged EO & EC: 5.0-305.0s | 305.0-605.0s | Total duration: 605.9s
#
#  Segmentation and merging complete: all joint files saved successfully.
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\1449768905.py:95: RuntimeWarning: This filename (c:\Users\User\Desktop\TCS-PROJECTS\Project-1-EEG-SIGNALS-PAIN\Segment-Joined\ID9_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   combined_raw.save(save_dir / f"{f.stem}_combine.fif", overwrite=True)

# %%
import os

# Folder containing all files
folder_path = "Segment-Joined"

# Counters
count_fif = 0
count_npy = 0

# Loop through files and count
for file in os.listdir(folder_path):
    if file.endswith(".fif"):
        count_fif += 1
    elif file.endswith(".npy"):
        count_npy += 1

# Total files
total_files = count_fif + count_npy

# Print results
print(f"\nFolder: {folder_path}")
print(f"  Total files: {total_files}")
print(f"  .fif files: {count_fif}")
print(f"  .npy files: {count_npy}")
# Out:
# Folder: Segment-Joined
#   Total files: 74
#   .fif files: 37
#   .npy files: 37

# %%
# Information about .fif files in Segment-Joined folder

import os
import mne

# Folder containing all files
folder_path = "Segment-Joined"

print(f"\n=== {folder_path} Folder ===")

# Loop through all files in the folder
for file in os.listdir(folder_path):
    if file.endswith(".fif"):
        file_path = os.path.join(folder_path, file)

        # Read the EEG data (without loading full data into memory)
        raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)

        # Extract info
        n_channels = len(raw.info['ch_names'])
        ch_names = raw.info['ch_names']
        sfreq = raw.info['sfreq']
        n_times = raw.n_times
        duration = n_times / sfreq

        print(f"\nFile: {file}")
        print(f"  Channels: {n_channels}")
        print(f"  Channel names: {ch_names}")
        print(f"  Sampling frequency: {sfreq} Hz")
        print(f"  Time points: {n_times}")
        print(f"  Duration: {duration:.2f} seconds")

        print("-" * 50)
# Out:
# === Segment-Joined Folder ===
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID0_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID0_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 148750
#   Duration: 595.00 seconds
# --------------------------------------------------
#
# File: ID10_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID11_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID10_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID11_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID13_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID13_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID14_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID15(1)_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID14_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID15(1)_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID15_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID15_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID16_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID16_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID18_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID18_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID19_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID1_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID19_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID1_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID20_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID20_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID21_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID22_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID21_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID22_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID23_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID23_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID24_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID25_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID24_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID25_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID26_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID26_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 148750
#   Duration: 595.00 seconds
# --------------------------------------------------
#
# File: ID27_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID2_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID27_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID2_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID30_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID30_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID31_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID33_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID31_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID33_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID35_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID35_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID37_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID37_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID38_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID38_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID39_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID39_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID3_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID3_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID40_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID40_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID41_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID41_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID43_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID43_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID4_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID4_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID5_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID5_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID6_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID6_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID7_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID7_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID8_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)
# File: ID8_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
#
# File: ID9_combine.fif
#   Channels: 24
#   Channel names: ['FP1', 'FP2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T7', 'T8', 'P7', 'P8', 'Fz', 'Cz', 'Pz', 'M1', 'M2', 'AFz', 'CPz', 'POz']
#   Sampling frequency: 250.0 Hz
#   Time points: 150000
#   Duration: 600.00 seconds
# --------------------------------------------------
# C:\Users\User\AppData\Local\Temp\ipykernel_22436\3776766614.py:17: RuntimeWarning: This filename (Segment-Joined\ID9_combine.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(file_path, preload=False, verbose=False)

# %%
# Information about .npy files in Segment-Joined folder

import os
import numpy as np

# Folder containing all files
folder_path = "Segment-Joined"

print(f"\n=== {folder_path} Folder ===")

# Loop through all files in the folder
for file in os.listdir(folder_path):
    if file.endswith(".npy"):
        file_path = os.path.join(folder_path, file)

        # Load the .npy file
        data = np.load(file_path)

        # Display file info
        print(f"\nFile: {file}")
        print(f"  Shape: {data.shape}")
        print(f"  Data type: {data.dtype}")

        if len(data.shape) == 2:
            print(f"  -> Likely {data.shape[0]} channels × {data.shape[1]} samples")
# Out:
# === Segment-Joined Folder ===
#
# File: ID0_combine.npy
#   Shape: (24, 148750)
#   Data type: float64
#   -> Likely 24 channels × 148750 samples
#
# File: ID10_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID11_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID13_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID14_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID15(1)_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID15_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID16_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID18_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID19_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID1_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID20_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID21_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID22_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID23_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID24_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID25_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID26_combine.npy
#   Shape: (24, 148750)
#   Data type: float64
#   -> Likely 24 channels × 148750 samples
#
# File: ID27_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID2_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID30_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID31_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID33_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID35_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID37_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID38_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID39_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID3_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID40_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID41_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID43_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID4_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID5_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID6_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID7_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID8_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples
#
# File: ID9_combine.npy
#   Shape: (24, 150000)
#   Data type: float64
#   -> Likely 24 channels × 150000 samples

# %%
import mne
import numpy as np
from pathlib import Path

# Directory containing your processed files
DATA_DIR = Path("Segment-Joined")  # This is your new folder with combined files
SAMPLING_RATE = 250  # Hz,
EXPECTED_SEGMENT_SEC = [300, 600]  # 5 min or 10 min possible

print(f"\nChecking all .fif and .npy files in: {DATA_DIR}\n{'='*80}")

for file in sorted(DATA_DIR.glob("*")):
    if file.suffix == ".fif":
        raw = mne.io.read_raw_fif(file, preload=False, verbose="ERROR")
        n_channels = len(raw.ch_names)
        n_samples = raw.n_times
        duration_sec = n_samples / SAMPLING_RATE

        # Status check based on expected segment lengths
        status = (
            "✅ Exact 5 min"
            if abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[FIF] {file.name}")
        print(f"   Channels: {n_channels}, Samples: {n_samples}, Duration: {duration_sec:.2f}s → {status}")

    elif file.suffix == ".npy":
        data = np.load(file)
        if data.ndim == 2:
            n_channels, n_samples = data.shape
        elif data.ndim == 3:
            n_channels, n_samples, _ = data.shape
        else:
            n_channels, n_samples = "?", "?"

        duration_sec = n_samples / SAMPLING_RATE if isinstance(n_samples, int) else "?"
        status = (
            "✅ Exact 5 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 300) < 0.5
            else "✅ Exact 10 min"
            if isinstance(duration_sec, float) and abs(duration_sec - 600) < 0.5
            else "⚠️ Irregular length"
        )

        print(f"[NPY] {file.name}")
        print(f"   Shape: {data.shape}, Duration: {duration_sec}s → {status}")

print("\nCheck complete ✅\n")
# Out:
# Checking all .fif and .npy files in: Segment-Joined
# ================================================================================
# [FIF] ID0_combine.fif
#    Channels: 24, Samples: 148750, Duration: 595.00s → ⚠️ Irregular length
# [NPY] ID0_combine.npy
#    Shape: (24, 148750), Duration: 595.0s → ⚠️ Irregular length
# [FIF] ID10_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID10_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID11_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID11_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID13_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID13_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID14_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID14_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID15(1)_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID15(1)_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID15_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID15_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID16_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID16_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID18_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID18_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID19_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID19_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID1_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID1_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID20_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID20_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID21_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID21_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID22_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID22_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID23_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID23_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID24_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID24_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID25_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID25_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID26_combine.fif
#    Channels: 24, Samples: 148750, Duration: 595.00s → ⚠️ Irregular length
# [NPY] ID26_combine.npy
#    Shape: (24, 148750), Duration: 595.0s → ⚠️ Irregular length
# [FIF] ID27_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID27_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID2_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID2_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID30_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID30_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID31_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID31_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID33_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID33_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID35_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID35_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID37_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID37_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID38_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID38_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID39_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID39_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID3_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID3_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID40_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID40_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID41_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID41_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID43_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID43_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID4_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID4_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID5_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID5_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID6_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID6_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID7_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID7_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID8_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID8_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
# [FIF] ID9_combine.fif
#    Channels: 24, Samples: 150000, Duration: 600.00s → ✅ Exact 10 min
# [NPY] ID9_combine.npy
#    Shape: (24, 150000), Duration: 600.0s → ✅ Exact 10 min
#
# Check complete ✅
